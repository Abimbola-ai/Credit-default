# %% [markdown]
# ### Kowope Mart is a Nigerian-based retail company with a vision to provide quality goods, education and automobile services to its customers at affordable price and reduce if not eradicate charges on card payments and increase customer satisfaction with credit rewards that can be used within the Mall. To achieve this, the company has partnered with DSBank on co-branded credit card with additional functionality such that customers can request for loan, pay for goods even with zero-balance and then pay back within an agreed period of time.
#
# ### This innovative strategy has increased sales for the company. However, there has been recent cases of credit defaults and Kowope Mart will like to have a system that profiles customers who are worthy of the card with minimum if not zero risk of defaulting.You have been employed as a Data Scientist to leverage Machine learning to predict customers who are likely to default or not.This is Qualification Competition for the Data Science Nigeria AI Bootcamp.

# %% [markdown]
# ## The data is a structure dataset pull from the Kowope Mart’s database with few important features that can be used to predict defaulters in retail network. The data sample has been split into train and test with a volume of 56,000 and 24,000.
#
# ## The files for download are:
# ### train.csv - you will use this to train your model.
# ### test.csv - you will use this to test your model.
# ### SampleSubmission.csv - is an example of what your submission file should look like. The order of the rows does not matter, but the names of the UIDs must be correct. You must predict growth_stage for the corresponding images.

# %% [markdown]
# ## Variables
#
# ##### Application_ID: Unique Customer Application Identification number
#
#
#
# ### Risk Scoring features: There's a minimum payments you are expected to make on your lines of credit or credit cards at certain periods, when you miss those payments. Your credit score is affected and you are in delinquency period. Every credit cards and lines of credits impacts Risk scoring significantly. High credit card balance could lower your credit scores even with one time payments, if it raises your credit utilization ratio. Scoring models don't consider lines of credit when calculating revolving utilization ratio.
#
# #### form_field1: Customer Creditworthiness score based on historical data.
# ###### (Important feature affected by repayment history, type of credit, new credit, current debt, length of credit. (Determines ability to borrow money, ranks borrower's riskiness but not borrower's default probability, does not account for economic conditions). 800-850 excellent, Very good 740-799, Good 670-739, Fair 580-669, Poor 300-579. Payment history accounts for 35% of credit score, Total owed 30%, Length of credit history counts 15% longer credit histories 10% type of credits, new credits 10% credit inquiries
#
# ##### form_field2: A score that measures the number and riskiness of credit enquiries made by a borrower. (Related to no of enquiries for credit. usually there is a riskiness limit, the more the riskier. (studies show people with 6-8 inquiries are more likely to file for bankruptcy). Multiple enquiries lowers your credit score
#
# ### Severity features: Severity is a function of amount, time since default, and number of defaults
#
# #### form_field3: Severity of default by the borrower on any loan(s).
# #### form_field4: Severity of default by the borrower on auto loan(s). (Auto loans are usually backed by collateral)
# #### form_field5: Severity of default by the borrower on education loan(s).
#
#
# ### Credit features
# #### form_field6: Minimum of credit available on all credit cards that is automatically renewed as debts are paid off on the customer’s cards (in NGN) (The smaller credit limit of a particular card)
# #### form_field7: Maximum of credit available on customer’s active credit lines (in NGN)
# #### form_field8: Maximum of credit available on all active credit cards that is automatically renewed as debts are paid off on the customer’s cards (in NGN) (Max credit limit of a card)
# #### form_field9: Sum of available credit on credit cards that the borrower has missed 1 payment (in NGN)  (Borrower already missed one payment, is currently in deliquency period before default. What is now the sum of available credit on those credit cards, is borrower still nearing default.
# #### form_field10: Total amount of credit available on accepted credit lines (in NGN) (Credit status)
# #### form_field11: The amount of dues collected post-default where the due amount was more than 500 (in NGN) (penalty dues post-default collected)
# #### form_field12: Sum of the amount due on active credit cards (in NGN) (Statement balance)
# #### form_field13: Annual amount paid towards all credit cards during the previous year (in NGN)
# #### form_field14: Annual income (in NGN)
# #### form_field15: The estimated market value of a property owned/used by the borrower (in NGN)
#
#
# ### Credit card features:
# #### form_field16: Number of active credit card that is automatically renewed as debts are paid off on which full credit limit is utilized by the borrower
# #### form_field17: Number of active credit cards on which full credit limit is utilized by the borrower
# #### form_field18: Number of active credit lines on which full credit limit is utilized by the borrower
# #### form_field19: Number of active credit cards on which at least 75% credit limit is utilized by the borrower
# #### form_field20: Number of active credit lines on which at least 75% credit limit is utilized by the borrower
# #### form_field21: Average utilization of active revolving credit card loans (%)
# #### form_field22: Average utilization of line on all active credit lines activated in last 2 years (%)
# #### form_field23: Average utilization of line on all active credit cards activated in last 1 year (%)
# #### form_field24: Average utilization of line on credit cards on which the borrower has missed 1 payment during the last 6 months (%)
#
# ## Tenure is pre-agreed time period (in months or years) between the lender and borrower, for the borrower to repay the principal and interest in full to the lender
# #### form_field25: Average tenure of active revolving credit cards (in days) (Average tenure of revolving credits on credit cards, balance not paid yet)
# #### form_field26: Tenure of oldest credit card among all active credit cards (in days)
# #### form_field27: Tenure of oldest revolving credit card among all active revolving credit cards (in days)
#
#
# ### Time-related features:
# #### form_field28: Number of days since last missed payment on any credit line
# #### form_field29: Tenure of the oldest credit line (in days)
# #### form_field30: Maximum tenure on all auto loans (in days)
# #### form_field31: Maximum tenure on all education loans (in days)
# #### form_field32: Sum of tenures (in months) of active credit cards
# #### form_field33: Sum of tenures (in months) of active credit cards
# #### form_field34: Number of active credit lines over the last 6 months on which the borrower has missed 1 payment
# #### form_field35: Number of revolving credit cards over the last 2 years on which the borrower has missed 1 payment
# #### form_field36: Number of active credit lines
# #### form_field37: Number of credit cards with an active tenure of at least 2 years
# #### form_field38: Number of credit lines activated in the last 2 years
# #### form_field39: Number of credit lines on which the borrower has current delinquency (Period between missing a loan payment and having the loan default, it's like a grace period after loan expiry date before penalizing the borrower after missing a payment).
#
#
# ### Percentage related features:
# #### form_field40: Utilization of line on active education loans (%)
# #### form_field41: Utilization of line on active auto loans (%)
#
#
# ### Other features:
# #### form_field42: Financial stress index of the borrower. This index is a function of collection trades, bankruptcies files, tax liens invoked, etc.
# #### form_field43: Number of credit lines on which the borrower has never missed a payment in the last 2 years, yet considered as high-risk loans based on the market prediction of the economic scenario
# #### form_field44: Ratio of the maximum amount due on all active credit lines and the sum of amounts due on all active credit lines
# #### form_field45: Number of mortgage loans on which the borrower has missed 2 payments
# #### form_field46: Number of auto loans on which the borrower has missed 2 payments
# #### form_field47: Type of product that the applicant applied for. (C = Charge; L = Lending)
# #### form_field48: Undefined Variable
# #### form_field49: Undefined Variable
# #### form_field50: Ratio of the minimum amount due on all active credit lines and the sum of amounts due on all active credit lines
#
#
# ### Target features:
# #### default_status: defaulted or not. (yes:1, no: 0)

# %% [markdown]
# #### This risk prediction can be approached as a binary classification utilizing the most predictive features. In this notebook we focus on analyzing and preparing the data to achieve the optimum AUC score on the credit default risk prediction.

# %%
#import necessary dependecies
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
import math
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
import os
import warnings
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, log_loss
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from scipy.stats import mode
from sklearn.metrics import silhouette_score
from itertools import permutations
from tqdm import tqdm
import swifter
from itertools import combinations
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score, KFold, GridSearchCV, StratifiedKFold
from sklearn.metrics import balanced_accuracy_score, auc, mean_squared_error, roc_curve, confusion_matrix, precision_score, recall_score, f1_score,\
log_loss, roc_auc_score
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# %matplotlib inline
warnings.filterwarnings('ignore')
from typing import List

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Damola\\Desktop\\ZINDI COMPETITION\\DSN CREDIT DEFAULT'

# %%
#Load the datasets

train = pd.read_csv('Train.csv')

test = pd.read_csv('Test.csv')

submission = pd.read_csv('SampleSubmission.csv')

# %%
print(train.shape, test.shape, submission.shape)
# Out:
# (56000, 52) (24000, 51) (24000, 2)

# %%
train.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000000       3436.0      0.28505       1.6560          0.0
# 1  Apcnt_1000004       3456.0      0.67400       0.2342          0.0
# 2  Apcnt_1000008       3276.0      0.53845       3.1510          0.0
# 3  Apcnt_1000012       3372.0      0.17005       0.5050          0.0
# 4  Apcnt_1000016       3370.0      0.77270       1.1010          0.0
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0        0.000          0.0   10689720.0     252072.0    4272776.0  ...
# 1        0.000          0.0     898979.0     497531.0    9073814.0  ...
# 2        6.282          NaN     956940.0          NaN     192944.0  ...
# 3        0.000     192166.0    3044703.0     385499.0    3986472.0  ...
# 4        0.000       1556.0     214728.0     214728.0    1284089.0  ...
#
#    form_field42  form_field43  form_field44  form_field45  form_field46  \
# 0      0.392854          2.02      0.711632           0.0           0.0
# 1      0.314281          8.08      0.183584           NaN           0.0
# 2      0.162965         18.18      0.791136           0.0           0.0
# 3      0.488884          2.02      0.685168           NaN           0.0
# 4      0.275000         12.12      0.438168           0.0           0.0
#
#    form_field47  form_field48  form_field49  form_field50  default_status
# 0        charge           NaN      1.129518      0.044335              no
# 1        charge    349.805730      1.620483      0.322436              no
# 2        charge           NaN      1.513370      0.011640             yes
# 3        charge     89.940100      0.664452      0.082729              no
# 4        charge     97.887502      1.427891      0.045630              no
#
# [5 rows x 52 columns]

# %%
test.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000032       3236.0      0.34875      10.2006       0.0000
# 1  Apcnt_1000048       3284.0      1.27360       2.9606       9.0198
# 2  Apcnt_1000052          NaN      0.27505       0.0600       0.0000
# 3  Apcnt_1000076       3232.0      0.28505       2.8032       0.0000
# 4  Apcnt_1000080       3466.0      2.09545       0.8318       2.5182
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0          0.0     418564.0     418564.0     418564.0     540710.0  ...
# 1          0.0          0.0    9858816.0      49014.0    1510098.0  ...
# 2          0.0          NaN          NaN          NaN          NaN  ...
# 3          0.0          0.0     473802.0     473802.0    1724437.0  ...
# 4          0.0      19839.0    1150662.0    1150662.0    7860523.0  ...
#
#    form_field41  form_field42  form_field43  form_field44  form_field45  \
# 0           NaN      0.825000          1.01      0.800000           NaN
# 1       18.8415      0.507694          4.04      0.623248           1.0
# 2           NaN           NaN          0.00           NaN           NaN
# 3           NaN      0.916663          2.02      0.464224           NaN
# 4           NaN      0.234047         23.23      0.726688           0.0
#
#    form_field46  form_field47  form_field48  form_field49  form_field50
# 0           0.0        charge           NaN      0.000000      0.011221
# 1           0.0       lending           NaN      0.504974      0.043525
# 2           NaN        charge           NaN      0.000000           NaN
# 3           NaN        charge     90.163742      0.788809      0.104029
# 4           0.0       lending   1303.587148      1.637733      0.163124
#
# [5 rows x 51 columns]

# %%
submission.head()
# Out:
#     Applicant_ID  default_status
# 0  Apcnt_1000032               1
# 1  Apcnt_1000048               1
# 2  Apcnt_1000052               1
# 3  Apcnt_1000076               1
# 4  Apcnt_1000080               1

# %%
#Renaming the columns to make more interpretable

rename_col = {"form_field1":'Creditworth_score',
           "form_field2":'CreditEnquiredRisk',
           "form_field3":'LoanDefaultSeverityAll',
           "form_field4":'LoanDefaultSeverityAuto',
           "form_field5":'LoanDefaultSeverityEdu',
           "form_field6":'MinCreditAvailAfterPaymentsCards',
           "form_field7":'MaxCreditAvailActivelines',
           "form_field8":'MaxCreditAvailAfterPaymentsCards',
           "form_field9":'SumOfAvailCreditOnCardsMissed1Pay',
                                            
           "form_field10":'TotalCreditAvailActivelines',
           "form_field11":'PostDefaultDuesCollectedA500',
                                            
           "form_field12":'TotalDueActiveCards',
           "form_field13":'AnnualPaidPreviousYearAllCards',
                                            
           "form_field14":'AnnualIncome',
           "form_field15":'PropertyMarketValue',
                                            
           "form_field16":'NumActiveCCardsRenewedFullCreditUsed',
           "form_field17":'NumActiveCCardsFullCreditUsed',
                                            
           "form_field18":'NumActiveCLinesFullCreditUsed',
           "form_field19":'NumActiveCCards75pCreditUsed',
                                            
           "form_field20":'NumActiveCLines75pCreditUsed',
           "form_field21":'%AverageUtilCCard',
                                            
           "form_field22":'%AvgUtilOfCLines2Yrs',
           "form_field23":'%AvgUtilOfCCards1Yr',
                                            
           "form_field24":'%AvgUtilOfCLines6MoMiss1',
           "form_field25":'AvgTenureofActiveRevolveCardsinDays',
                                            
           "form_field26":'TenureofOldestCCardsinDays',
           "form_field27":'TenureofOldestRevolveCCardsinDays',
                                            
           "form_field28":'NumDaysonlastmissedCLine',
           "form_field29":'TenureofOldestCLineinDays',
                                            
           "form_field30":'MaxTenureonAutoLoansinDays',
           "form_field31":'MaxTenureonEduLoansinDays',
                                            
           "form_field32":'SumTenureonActiveCCardsinMonth',
           "form_field33":'SumTenureonActiveCLinesinMonth',
                                            
           "form_field34":'NumOfCLineslast6MoMiss1', 
           "form_field35":'NumOfRevolveCCardslast2YrMiss1',
                                            
           "form_field36":'NumActiveCLines',
           "form_field37":'NumCCardsActiveTenure2Yrs',
                                            
           "form_field38":'NumActivatedCLinesinlast2Yrs',
           "form_field39":'NumActiveCLinesDeliquent',
                                            
           "form_field40":'%UtilCLinesonEduLoan',
           "form_field41":'%UtilCLinesonAutoLoan',
                                            
           
           
           "form_field42":'FinanceStressIndex',
           "form_field43":'NumberCLinesPaidHighRisk',
                                            
           "form_field44":'RatioDueCCLinesMaxSumCCLines',
           "form_field45":'NumOfMortgageLoansMissed2x',
                                            
           "form_field46":'NumOfAutoLoansMissed2x',
           "form_field50": 'RatioDueCCLinesMinSumCCLines',
                                            
           'form_field47': 'ProductType', 
              
           'default_status_no': 'default_status'}

# %%
train = train.rename(columns = rename_col)

test = test.rename(columns = rename_col)

# %%
train.head()
# Out:
#     Applicant_ID  Creditworth_score  CreditEnquiredRisk  \
# 0  Apcnt_1000000             3436.0             0.28505
# 1  Apcnt_1000004             3456.0             0.67400
# 2  Apcnt_1000008             3276.0             0.53845
# 3  Apcnt_1000012             3372.0             0.17005
# 4  Apcnt_1000016             3370.0             0.77270
#
#    LoanDefaultSeverityAll  LoanDefaultSeverityAuto  LoanDefaultSeverityEdu  \
# 0                  1.6560                      0.0                   0.000
# 1                  0.2342                      0.0                   0.000
# 2                  3.1510                      0.0                   6.282
# 3                  0.5050                      0.0                   0.000
# 4                  1.1010                      0.0                   0.000
#
#    MinCreditAvailAfterPaymentsCards  MaxCreditAvailActivelines  \
# 0                               0.0                 10689720.0
# 1                               0.0                   898979.0
# 2                               NaN                   956940.0
# 3                          192166.0                  3044703.0
# 4                            1556.0                   214728.0
#
#    MaxCreditAvailAfterPaymentsCards  SumOfAvailCreditOnCardsMissed1Pay  ...  \
# 0                          252072.0                          4272776.0  ...
# 1                          497531.0                          9073814.0  ...
# 2                               NaN                           192944.0  ...
# 3                          385499.0                          3986472.0  ...
# 4                          214728.0                          1284089.0  ...
#
#    FinanceStressIndex  NumberCLinesPaidHighRisk  RatioDueCCLinesMaxSumCCLines  \
# 0            0.392854                      2.02                      0.711632
# 1            0.314281                      8.08                      0.183584
# 2            0.162965                     18.18                      0.791136
# 3            0.488884                      2.02                      0.685168
# 4            0.275000                     12.12                      0.438168
#
#    NumOfMortgageLoansMissed2x  NumOfAutoLoansMissed2x  ProductType  \
# 0                         0.0                     0.0       charge
# 1                         NaN                     0.0       charge
# 2                         0.0                     0.0       charge
# 3                         NaN                     0.0       charge
# 4                         0.0                     0.0       charge
#
#    form_field48  form_field49  RatioDueCCLinesMinSumCCLines  default_status
# 0           NaN      1.129518                      0.044335              no
# 1    349.805730      1.620483                      0.322436              no
# 2           NaN      1.513370                      0.011640             yes
# 3     89.940100      0.664452                      0.082729              no
# 4     97.887502      1.427891                      0.045630              no
#
# [5 rows x 52 columns]

# %%
test.head()
# Out:
#     Applicant_ID  Creditworth_score  CreditEnquiredRisk  \
# 0  Apcnt_1000032             3236.0             0.34875
# 1  Apcnt_1000048             3284.0             1.27360
# 2  Apcnt_1000052                NaN             0.27505
# 3  Apcnt_1000076             3232.0             0.28505
# 4  Apcnt_1000080             3466.0             2.09545
#
#    LoanDefaultSeverityAll  LoanDefaultSeverityAuto  LoanDefaultSeverityEdu  \
# 0                 10.2006                   0.0000                     0.0
# 1                  2.9606                   9.0198                     0.0
# 2                  0.0600                   0.0000                     0.0
# 3                  2.8032                   0.0000                     0.0
# 4                  0.8318                   2.5182                     0.0
#
#    MinCreditAvailAfterPaymentsCards  MaxCreditAvailActivelines  \
# 0                          418564.0                   418564.0
# 1                               0.0                  9858816.0
# 2                               NaN                        NaN
# 3                               0.0                   473802.0
# 4                           19839.0                  1150662.0
#
#    MaxCreditAvailAfterPaymentsCards  SumOfAvailCreditOnCardsMissed1Pay  ...  \
# 0                          418564.0                           540710.0  ...
# 1                           49014.0                          1510098.0  ...
# 2                               NaN                                NaN  ...
# 3                          473802.0                          1724437.0  ...
# 4                         1150662.0                          7860523.0  ...
#
#    %UtilCLinesonAutoLoan  FinanceStressIndex  NumberCLinesPaidHighRisk  \
# 0                    NaN            0.825000                      1.01
# 1                18.8415            0.507694                      4.04
# 2                    NaN                 NaN                      0.00
# 3                    NaN            0.916663                      2.02
# 4                    NaN            0.234047                     23.23
#
#    RatioDueCCLinesMaxSumCCLines  NumOfMortgageLoansMissed2x  \
# 0                      0.800000                         NaN
# 1                      0.623248                         1.0
# 2                           NaN                         NaN
# 3                      0.464224                         NaN
# 4                      0.726688                         0.0
#
#    NumOfAutoLoansMissed2x  ProductType  form_field48  form_field49  \
# 0                     0.0       charge           NaN      0.000000
# 1                     0.0      lending           NaN      0.504974
# 2                     NaN       charge           NaN      0.000000
# 3                     NaN       charge     90.163742      0.788809
# 4                     0.0      lending   1303.587148      1.637733
#
#    RatioDueCCLinesMinSumCCLines
# 0                      0.011221
# 1                      0.043525
# 2                           NaN
# 3                      0.104029
# 4                      0.163124
#
# [5 rows x 51 columns]

# %%
train.dtypes
# Out:
# Applicant_ID                             object
# Creditworth_score                       float64
# CreditEnquiredRisk                      float64
# LoanDefaultSeverityAll                  float64
# LoanDefaultSeverityAuto                 float64
# LoanDefaultSeverityEdu                  float64
# MinCreditAvailAfterPaymentsCards        float64
# MaxCreditAvailActivelines               float64
# MaxCreditAvailAfterPaymentsCards        float64
# SumOfAvailCreditOnCardsMissed1Pay       float64
# TotalCreditAvailActivelines             float64
# PostDefaultDuesCollectedA500            float64
# TotalDueActiveCards                     float64
# AnnualPaidPreviousYearAllCards          float64
# AnnualIncome                              int64
# PropertyMarketValue                     float64
# NumActiveCCardsRenewedFullCreditUsed    float64
# NumActiveCCardsFullCreditUsed           float64
# NumActiveCLinesFullCreditUsed           float64
# NumActiveCCards75pCreditUsed            float64
# NumActiveCLines75pCreditUsed            float64
# %AverageUtilCCard                       float64
# %AvgUtilOfCLines2Yrs                    float64
# %AvgUtilOfCCards1Yr                     float64
# %AvgUtilOfCLines6MoMiss1                float64
# AvgTenureofActiveRevolveCardsinDays     float64
# TenureofOldestCCardsinDays              float64
# TenureofOldestRevolveCCardsinDays       float64
# NumDaysonlastmissedCLine                float64
# TenureofOldestCLineinDays               float64
# MaxTenureonAutoLoansinDays              float64
# MaxTenureonEduLoansinDays               float64
# SumTenureonActiveCCardsinMonth          float64
# SumTenureonActiveCLinesinMonth          float64
# NumOfCLineslast6MoMiss1                 float64
# NumOfRevolveCCardslast2YrMiss1          float64
# NumActiveCLines                         float64
# NumCCardsActiveTenure2Yrs               float64
# NumActivatedCLinesinlast2Yrs            float64
# NumActiveCLinesDeliquent                float64
# %UtilCLinesonEduLoan                    float64
# %UtilCLinesonAutoLoan                   float64
# FinanceStressIndex                      float64
# NumberCLinesPaidHighRisk                float64
# RatioDueCCLinesMaxSumCCLines            float64
# NumOfMortgageLoansMissed2x              float64
# NumOfAutoLoansMissed2x                  float64
# ProductType                              object
# form_field48                            float64
# form_field49                            float64
# RatioDueCCLinesMinSumCCLines            float64
# default_status                           object
# dtype: object

# %% [markdown]
# Mostly numerical variables with ProductType categorical

# %% [markdown]
# ## EDA:

# %% [markdown]
# ### Data Overview:

# %%
#Merging train and test for joint analysis

train['combiner'] = 'x'
test['combiner'] = 'y'

# %%
data = pd.concat([train, test])

# %%
data.reset_index(drop = True, inplace = True)

# %%
data.head()
# Out:
#    %AverageUtilCCard  %AvgUtilOfCCards1Yr  %AvgUtilOfCLines2Yrs  \
# 0            134.655                  NaN                   NaN
# 1            109.230             14584.29              11385.24
# 2                NaN                  NaN                   NaN
# 3            120.120                 0.00               8580.00
# 4            104.535             10326.45               8360.19
#
#    %AvgUtilOfCLines6MoMiss1  %UtilCLinesonAutoLoan  %UtilCLinesonEduLoan  \
# 0                   134.655                    NaN                   NaN
# 1                    86.685                    NaN                   NaN
# 2                       NaN                    NaN              149.6805
# 3                    85.800                    NaN                   NaN
# 4                   115.335                    NaN              150.0135
#
#    AnnualIncome  AnnualPaidPreviousYearAllCards   Applicant_ID  \
# 0      96375139                       7875694.0  Apcnt_1000000
# 1      28141427                       2141445.0  Apcnt_1000004
# 2      16576457                             0.0  Apcnt_1000008
# 3      48187375                       1186839.0  Apcnt_1000012
# 4      28141427                        511535.0  Apcnt_1000016
#
#    AvgTenureofActiveRevolveCardsinDays  ...  SumTenureonActiveCLinesinMonth  \
# 0                               4000.5  ...                          8.0000
# 1                               4161.0  ...                         17.5000
# 2                               1597.5  ...                          0.6666
# 3                               1701.0  ...                          7.8334
# 4                               1551.0  ...                          1.0000
#
#    TenureofOldestCCardsinDays  TenureofOldestCLineinDays  \
# 0                     17064.0                    17064.0
# 1                     13413.0                    13413.0
# 2                      4746.0                    15696.0
# 3                      4014.0                    11679.0
# 4                      3285.0                    19437.0
#
#    TenureofOldestRevolveCCardsinDays  TotalCreditAvailActivelines  \
# 0                            11376.0                   11333126.0
# 1                             8942.0                    2533168.0
# 2                             3164.0                    1079864.0
# 3                             2676.0                    3621979.0
# 4                             2190.0                     361770.0
#
#    TotalDueActiveCards  combiner  default_status  form_field48  form_field49
# 0            2301324.0         x              no           NaN      1.129518
# 1            3982971.0         x              no    349.805730      1.620483
# 2                  NaN         x             yes           NaN      1.513370
# 3             771776.0         x              no     89.940100      0.664452
# 4             818456.0         x              no     97.887502      1.427891
#
# [5 rows x 53 columns]

# %%
data.tail()
# Out:
#        %AverageUtilCCard  %AvgUtilOfCCards1Yr  %AvgUtilOfCLines2Yrs  \
# 79995                NaN                  NaN                   NaN
# 79996            123.195                  NaN             11663.055
# 79997                NaN                  NaN             13080.000
# 79998            129.435            13024.995             13024.995
# 79999                NaN                  NaN                   NaN
#
#        %AvgUtilOfCLines6MoMiss1  %UtilCLinesonAutoLoan  %UtilCLinesonEduLoan  \
# 79995                       NaN                92.6910                   NaN
# 79996                   123.195               125.0220                   NaN
# 79997                       NaN                    NaN                   NaN
# 79998                   138.450                31.1955                   NaN
# 79999                   124.980               112.3035                   NaN
#
#        AnnualIncome  AnnualPaidPreviousYearAllCards  Applicant_ID  \
# 79995      21973443                             0.0  Apcnt_999940
# 79996      96375139                      97696961.0  Apcnt_999956
# 79997      21973443                             0.0  Apcnt_999976
# 79998      16576457                        673748.0  Apcnt_999984
# 79999      48187375                       3031477.0  Apcnt_999992
#
#        AvgTenureofActiveRevolveCardsinDays  ...  \
# 79995                                547.5  ...
# 79996                               1485.0  ...
# 79997                               2304.0  ...
# 79998                                706.5  ...
# 79999                               9319.5  ...
#
#        SumTenureonActiveCLinesinMonth  TenureofOldestCCardsinDays  \
# 79995                          0.3334                         NaN
# 79996                         14.1666                      6387.0
# 79997                          5.3334                         NaN
# 79998                          2.6666                      2463.0
# 79999                         24.8334                     30204.0
#
#        TenureofOldestCLineinDays  TenureofOldestRevolveCCardsinDays  \
# 79995                     3741.0                                NaN
# 79996                    14691.0                             4258.0
# 79997                    10038.0                                NaN
# 79998                     6297.0                             1642.0
# 79999                    30204.0                            20136.0
#
#        TotalCreditAvailActivelines  TotalDueActiveCards  combiner  \
# 79995                    2280318.0                  NaN         y
# 79996                   12999991.0           48989882.0         y
# 79997                      49403.0                  NaN         y
# 79998                    2551062.0             355935.0         y
# 79999                    5361587.0                  0.0         y
#
#        default_status  form_field48  form_field49
# 79995             NaN           NaN      0.000000
# 79996             NaN   4200.072959      3.000000
# 79997             NaN           NaN      4.855060
# 79998             NaN     27.325129      0.818733
# 79999             NaN           NaN      0.000000
#
# [5 rows x 53 columns]

# %%
data.describe()
# Out:
#        %AverageUtilCCard  %AvgUtilOfCCards1Yr  %AvgUtilOfCLines2Yrs  \
# count       57439.000000         39752.000000          50876.000000
# mean           86.685145          6458.894743           6635.784763
# std            53.365748          5797.309660           5673.072482
# min             0.255000             0.000000              0.000000
# 25%            40.395000           811.736250           1090.072500
# 50%            89.535000          5550.000000           5961.637500
# 75%           129.930000         11281.425000          11368.946250
# max          1957.875000        186799.995000          97200.000000
#
#        %AvgUtilOfCLines6MoMiss1  %UtilCLinesonAutoLoan  %UtilCLinesonEduLoan  \
# count              61098.000000           25422.000000          17443.000000
# mean                 104.972751             108.145137            147.746178
# std                  450.120664              36.663235             44.643599
# min                    0.000000               0.000000              0.021000
# 25%                   14.838750              87.229500            136.033500
# 50%                   60.660000             118.325250            150.000000
# 75%                  114.810000             137.459625            167.547000
# max                41801.100000             255.000000            645.450000
#
#        AnnualIncome  AnnualPaidPreviousYearAllCards  \
# count  8.000000e+04                    7.164800e+04
# mean   7.627971e+07                    6.002145e+06
# std    3.068579e+09                    2.226305e+07
# min    0.000000e+00                    0.000000e+00
# 25%    1.657646e+07                    1.941110e+05
# 50%    2.814143e+07                    1.591010e+06
# 75%    4.818738e+07                    5.590027e+06
# max    3.854990e+11                    2.457824e+09
#
#        AvgTenureofActiveRevolveCardsinDays  CreditEnquiredRisk  ...  \
# count                         72294.000000        74447.000000  ...
# mean                           2625.097954            0.552815  ...
# std                            1959.001865            0.822650  ...
# min                               0.000000            0.000000  ...
# 25%                            1231.500000            0.070050  ...
# 50%                            2208.000000            0.269450  ...
# 75%                            3529.125000            0.722525  ...
# max                           25093.500000           22.315050  ...
#
#        SumOfAvailCreditOnCardsMissed1Pay  SumTenureonActiveCCardsinMonth  \
# count                       6.859200e+04                    72294.000000
# mean                        1.326390e+07                      940.861759
# std                         2.076362e+07                     1048.641698
# min                         0.000000e+00                        0.000000
# 25%                         1.360722e+06                      194.000000
# 50%                         5.512519e+06                      600.000000
# 75%                         1.705911e+07                     1334.000000
# max                         1.443921e+09                    21306.000000
#
#        SumTenureonActiveCLinesinMonth  TenureofOldestCCardsinDays  \
# count                    78249.000000                69390.000000
# mean                        13.993114                10107.365543
# std                         15.300278                 8793.726717
# min                          0.166600                    0.000000
# 25%                          2.333400                 3375.000000
# 50%                          7.833400                 8214.000000
# 75%                         21.333400                14145.000000
# max                        152.000000                73275.000000
#
#        TenureofOldestCLineinDays  TenureofOldestRevolveCCardsinDays  \
# count               79498.000000                       66791.000000
# mean                16515.352235                        6193.160306
# std                  9667.958861                        5390.116309
# min                     0.000000                           0.000000
# 25%                  9765.000000                        2068.000000
# 50%                 15057.000000                        5110.000000
# 75%                 21810.000000                        8638.000000
# max                 73914.000000                       44104.000000
#
#        TotalCreditAvailActivelines  TotalDueActiveCards  form_field48  \
# count                 7.949800e+04         6.592200e+04  5.018900e+04
# mean                  1.186153e+07         2.771394e+06  3.041331e+05
# std                   2.613218e+07         4.621145e+06  1.717065e+06
# min                   0.000000e+00         0.000000e+00  0.000000e+00
# 25%                   4.411260e+05         2.746340e+05  7.706548e+01
# 50%                   3.692582e+06         1.158248e+06  3.167076e+02
# 75%                   1.323592e+07         3.368740e+06  1.167000e+03
# max                   2.191361e+09         1.609235e+08  1.213991e+08
#
#        form_field49
# count  79499.000000
# mean       1.053579
# std        1.809372
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.200961
# max       28.000000
#
# [8 rows x 49 columns]

# %%
data.isnull().sum()
# Out:
# %AverageUtilCCard                       22561
# %AvgUtilOfCCards1Yr                     40248
# %AvgUtilOfCLines2Yrs                    29124
# %AvgUtilOfCLines6MoMiss1                18902
# %UtilCLinesonAutoLoan                   54578
# %UtilCLinesonEduLoan                    62557
# AnnualIncome                                0
# AnnualPaidPreviousYearAllCards           8352
# Applicant_ID                                0
# AvgTenureofActiveRevolveCardsinDays      7706
# CreditEnquiredRisk                       5553
# Creditworth_score                        3639
# FinanceStressIndex                       1901
# LoanDefaultSeverityAll                    501
# LoanDefaultSeverityAuto                   501
# LoanDefaultSeverityEdu                    501
# MaxCreditAvailActivelines                7394
# MaxCreditAvailAfterPaymentsCards        18964
# MaxTenureonAutoLoansinDays              36417
# MaxTenureonEduLoansinDays               56218
# MinCreditAvailAfterPaymentsCards        18964
# NumActivatedCLinesinlast2Yrs              502
# NumActiveCCards75pCreditUsed                4
# NumActiveCCardsFullCreditUsed           15846
# NumActiveCCardsRenewedFullCreditUsed    18510
# NumActiveCLines                          2898
# NumActiveCLines75pCreditUsed              502
# NumActiveCLinesDeliquent                 6040
# NumActiveCLinesFullCreditUsed           14771
# NumCCardsActiveTenure2Yrs                7706
# NumDaysonlastmissedCLine                  502
# NumOfAutoLoansMissed2x                  22789
# NumOfCLineslast6MoMiss1                   502
# NumOfMortgageLoansMissed2x              44855
# NumOfRevolveCCardslast2YrMiss1          33014
# NumberCLinesPaidHighRisk                  818
# PostDefaultDuesCollectedA500            44819
# ProductType                                 0
# PropertyMarketValue                     32067
# RatioDueCCLinesMaxSumCCLines             7745
# RatioDueCCLinesMinSumCCLines            15853
# SumOfAvailCreditOnCardsMissed1Pay       11408
# SumTenureonActiveCCardsinMonth           7706
# SumTenureonActiveCLinesinMonth           1751
# TenureofOldestCCardsinDays              10610
# TenureofOldestCLineinDays                 502
# TenureofOldestRevolveCCardsinDays       13209
# TotalCreditAvailActivelines               502
# TotalDueActiveCards                     14078
# combiner                                    0
# default_status                          24000
# form_field48                            29811
# form_field49                              501
# dtype: int64

# %% [markdown]
# There are significant null values, not all credit variables is available.

# %%
#Percentage of null values per feature

data.isnull().sum()/len(data)
# Out:
# %AverageUtilCCard                       0.282012
# %AvgUtilOfCCards1Yr                     0.503100
# %AvgUtilOfCLines2Yrs                    0.364050
# %AvgUtilOfCLines6MoMiss1                0.236275
# %UtilCLinesonAutoLoan                   0.682225
# %UtilCLinesonEduLoan                    0.781963
# AnnualIncome                            0.000000
# AnnualPaidPreviousYearAllCards          0.104400
# Applicant_ID                            0.000000
# AvgTenureofActiveRevolveCardsinDays     0.096325
# CreditEnquiredRisk                      0.069413
# Creditworth_score                       0.045488
# FinanceStressIndex                      0.023762
# LoanDefaultSeverityAll                  0.006262
# LoanDefaultSeverityAuto                 0.006262
# LoanDefaultSeverityEdu                  0.006262
# MaxCreditAvailActivelines               0.092425
# MaxCreditAvailAfterPaymentsCards        0.237050
# MaxTenureonAutoLoansinDays              0.455213
# MaxTenureonEduLoansinDays               0.702725
# MinCreditAvailAfterPaymentsCards        0.237050
# NumActivatedCLinesinlast2Yrs            0.006275
# NumActiveCCards75pCreditUsed            0.000050
# NumActiveCCardsFullCreditUsed           0.198075
# NumActiveCCardsRenewedFullCreditUsed    0.231375
# NumActiveCLines                         0.036225
# NumActiveCLines75pCreditUsed            0.006275
# NumActiveCLinesDeliquent                0.075500
# NumActiveCLinesFullCreditUsed           0.184638
# NumCCardsActiveTenure2Yrs               0.096325
# NumDaysonlastmissedCLine                0.006275
# NumOfAutoLoansMissed2x                  0.284863
# NumOfCLineslast6MoMiss1                 0.006275
# NumOfMortgageLoansMissed2x              0.560688
# NumOfRevolveCCardslast2YrMiss1          0.412675
# NumberCLinesPaidHighRisk                0.010225
# PostDefaultDuesCollectedA500            0.560238
# ProductType                             0.000000
# PropertyMarketValue                     0.400838
# RatioDueCCLinesMaxSumCCLines            0.096812
# RatioDueCCLinesMinSumCCLines            0.198162
# SumOfAvailCreditOnCardsMissed1Pay       0.142600
# SumTenureonActiveCCardsinMonth          0.096325
# SumTenureonActiveCLinesinMonth          0.021888
# TenureofOldestCCardsinDays              0.132625
# TenureofOldestCLineinDays               0.006275
# TenureofOldestRevolveCCardsinDays       0.165112
# TotalCreditAvailActivelines             0.006275
# TotalDueActiveCards                     0.175975
# combiner                                0.000000
# default_status                          0.300000
# form_field48                            0.372638
# form_field49                            0.006262
# dtype: float64

# %% [markdown]
# Initially we will leave all null values and build a baseline model with null values, also as we continue with analysis, we will decide how to handle nulls per features.

# %%
#Categorical variables

data.describe(include = 'object')
# Out:
#          Applicant_ID ProductType combiner default_status
# count           80000       80000    80000          56000
# unique          80000           2        2              2
# top     Apcnt_1021048      charge        x             no
# freq                1       51840    56000          42285

# %%
data['Applicant_ID'].nunique()
# Out:
# 80000

# %%
#Checking duplicated columns

len(data[data.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Build Quick Baseline Model

# %%
#Label Encode Product Type

labenc = LabelEncoder()

data['ProductType'] = labenc.fit_transform (data['ProductType'])

# %%
# imp_cols = list(set(data.columns) - set(data[['Applicant_ID', 'combiner','default_status']]))

# %%
# data_imp = data.copy()

# %%
# imp_mean =SimpleImputer(missing_values = np.nan, strategy = 'mean')

# data_imp[imp_cols] = imp_mean.fit_transform(data_imp[imp_cols])

# %%
train = data[data['combiner'] == 'x']

# %%
labstat = LabelEncoder()

train['default_status'] = labstat.fit_transform(train['default_status'])

# %%
target = train[['default_status']]

# %% [markdown]
# #### LightGbm Baseline

# %%
target['default_status']
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
# 5        0
# 6        1
# 7        0
# 8        0
# 9        1
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       0
# 16       1
# 17       0
# 18       1
# 19       0
# 20       0
# 21       0
# 22       1
# 23       0
# 24       0
# 25       0
# 26       0
# 27       0
# 28       0
# 29       1
#         ..
# 55970    1
# 55971    0
# 55972    0
# 55973    0
# 55974    1
# 55975    0
# 55976    0
# 55977    0
# 55978    0
# 55979    0
# 55980    0
# 55981    0
# 55982    0
# 55983    0
# 55984    0
# 55985    0
# 55986    1
# 55987    0
# 55988    0
# 55989    1
# 55990    0
# 55991    1
# 55992    0
# 55993    0
# 55994    1
# 55995    0
# 55996    1
# 55997    0
# 55998    0
# 55999    0
# Name: default_status, Length: 56000, dtype: int32

# %%
#Cross-Validation routine

from lightgbm import LGBMClassifier

from xgboost import XGBClassifier

rand = 40

fold = StratifiedKFold(n_splits= 5, shuffle= True, random_state= rand)

i = 1

err = []

#Standardize
#scaler = StandardScaler()

for train_index, test_index in fold.split(train, target):

    print('fold n°: ', i)

    x_data, x_val = train.iloc[train_index], train.iloc[test_index]

    y_data, y_val = target.iloc[train_index], target.iloc[test_index]
    
    

    x_data = x_data.drop(['default_status','combiner', 'Applicant_ID'], axis = 1)
    
    x_val = x_val.drop(['default_status','combiner', 'Applicant_ID'], axis = 1)
    
    
#     x_data['ProductType'].fillna(0.5, inplace = True)
    
#     x_val['ProductType'].fillna(0.5, inplace = True)
    
  
    lgb_model = LGBMClassifier(n_estimators = 1100, learning_rate = 0.01,  reg_lambda = 10, random_state = rand)
    
#     'subsample': 0.4, 'reg_alpha': 5, 'n_estimators': 1200, 'min_child_weight': 1, \
#                     'max_depth': 6, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.8}

     
        
    lgb_model.fit(x_data, y_data['default_status'].ravel(), eval_set= [(x_val, y_val['default_status'].ravel())], \
              early_stopping_rounds= 500,\
              verbose= 100, eval_metric = ['auc'])
        
    y_train_pred = lgb_model.predict_proba(x_data)[:,1]

    y_test_pred = lgb_model.predict_proba(x_val)[:,1]
    
    
    
        
    print('auc train', roc_auc_score(y_data, y_train_pred))
    print('auc test',  roc_auc_score(y_val, y_test_pred))
    
    
    
    err.append(roc_auc_score(y_val, y_test_pred))


    i = i + 1
        
print('Mean auc test: ', np.mean(err))
# Out:
# fold n°:  1
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's binary_logloss: 0.450922	valid_0's auc: 0.826648
# [200]	valid_0's binary_logloss: 0.423654	valid_0's auc: 0.832292
# [300]	valid_0's binary_logloss: 0.414525	valid_0's auc: 0.834671
# [400]	valid_0's binary_logloss: 0.410603	valid_0's auc: 0.836519
# [500]	valid_0's binary_logloss: 0.408954	valid_0's auc: 0.837444
# [600]	valid_0's binary_logloss: 0.40813	valid_0's auc: 0.838039
# [700]	valid_0's binary_logloss: 0.407792	valid_0's auc: 0.838232
# [800]	valid_0's binary_logloss: 0.407628	valid_0's auc: 0.838328
# [900]	valid_0's binary_logloss: 0.407386	valid_0's auc: 0.838515
# [1000]	valid_0's binary_logloss: 0.407278	valid_0's auc: 0.838578
# [1100]	valid_0's binary_logloss: 0.407193	valid_0's auc: 0.838661
# Did not meet early stopping. Best iteration is:
# [1063]	valid_0's binary_logloss: 0.407183	valid_0's auc: 0.838672
# auc train 0.8851631215833947
# auc test 0.8386718279011436
# fold n°:  2
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's binary_logloss: 0.450921	valid_0's auc: 0.825187
# [200]	valid_0's binary_logloss: 0.423289	valid_0's auc: 0.831567
# [300]	valid_0's binary_logloss: 0.413972	valid_0's auc: 0.834278
# [400]	valid_0's binary_logloss: 0.40961	valid_0's auc: 0.836515
# [500]	valid_0's binary_logloss: 0.407314	valid_0's auc: 0.838002
# [600]	valid_0's binary_logloss: 0.406139	valid_0's auc: 0.838908
# [700]	valid_0's binary_logloss: 0.40559	valid_0's auc: 0.839298
# [800]	valid_0's binary_logloss: 0.405108	valid_0's auc: 0.839695
# [900]	valid_0's binary_logloss: 0.404782	valid_0's auc: 0.84002
# [1000]	valid_0's binary_logloss: 0.4046	valid_0's auc: 0.840145
# [1100]	valid_0's binary_logloss: 0.404511	valid_0's auc: 0.840195
# Did not meet early stopping. Best iteration is:
# [1099]	valid_0's binary_logloss: 0.404505	valid_0's auc: 0.840201
# auc train 0.8852545240120391
# auc test 0.8402006315235606
# fold n°:  3
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's binary_logloss: 0.45135	valid_0's auc: 0.825914
# [200]	valid_0's binary_logloss: 0.423911	valid_0's auc: 0.832024
# [300]	valid_0's binary_logloss: 0.414367	valid_0's auc: 0.834962
# [400]	valid_0's binary_logloss: 0.410289	valid_0's auc: 0.836821
# [500]	valid_0's binary_logloss: 0.408258	valid_0's auc: 0.838076
# [600]	valid_0's binary_logloss: 0.407155	valid_0's auc: 0.838871
# [700]	valid_0's binary_logloss: 0.406469	valid_0's auc: 0.839473
# [800]	valid_0's binary_logloss: 0.406039	valid_0's auc: 0.839866
# [900]	valid_0's binary_logloss: 0.405823	valid_0's auc: 0.840042
# [1000]	valid_0's binary_logloss: 0.405712	valid_0's auc: 0.840122
# [1100]	valid_0's binary_logloss: 0.405672	valid_0's auc: 0.84017
# Did not meet early stopping. Best iteration is:
# [1092]	valid_0's binary_logloss: 0.405661	valid_0's auc: 0.840175
# auc train 0.884828191292693
# auc test 0.8401754564522781
# fold n°:  4
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's binary_logloss: 0.45231	valid_0's auc: 0.822684
# [200]	valid_0's binary_logloss: 0.426094	valid_0's auc: 0.828297
# [300]	valid_0's binary_logloss: 0.417173	valid_0's auc: 0.831164
# [400]	valid_0's binary_logloss: 0.413673	valid_0's auc: 0.8331
# [500]	valid_0's binary_logloss: 0.41211	valid_0's auc: 0.83419
# [600]	valid_0's binary_logloss: 0.411084	valid_0's auc: 0.835086
# [700]	valid_0's binary_logloss: 0.410358	valid_0's auc: 0.835793
# [800]	valid_0's binary_logloss: 0.410009	valid_0's auc: 0.836118
# [900]	valid_0's binary_logloss: 0.409735	valid_0's auc: 0.83637
# [1000]	valid_0's binary_logloss: 0.409616	valid_0's auc: 0.836463
# [1100]	valid_0's binary_logloss: 0.409432	valid_0's auc: 0.836635
# Did not meet early stopping. Best iteration is:
# [1096]	valid_0's binary_logloss: 0.409415	valid_0's auc: 0.836653
# auc train 0.88567700530112
# auc test 0.8366528863326994
# fold n°:  5
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's binary_logloss: 0.449354	valid_0's auc: 0.830615
# [200]	valid_0's binary_logloss: 0.421331	valid_0's auc: 0.835899
# [300]	valid_0's binary_logloss: 0.411094	valid_0's auc: 0.839172
# [400]	valid_0's binary_logloss: 0.406715	valid_0's auc: 0.841469
# [500]	valid_0's binary_logloss: 0.404772	valid_0's auc: 0.842708
# [600]	valid_0's binary_logloss: 0.403755	valid_0's auc: 0.843455
# [700]	valid_0's binary_logloss: 0.403058	valid_0's auc: 0.844036
# [800]	valid_0's binary_logloss: 0.40258	valid_0's auc: 0.844411
# [900]	valid_0's binary_logloss: 0.402391	valid_0's auc: 0.84455
# [1000]	valid_0's binary_logloss: 0.402344	valid_0's auc: 0.844585
# [1100]	valid_0's binary_logloss: 0.40228	valid_0's auc: 0.844646
# Did not meet early stopping. Best iteration is:
# [1082]	valid_0's binary_logloss: 0.402261	valid_0's auc: 0.844661
# auc train 0.8842567557023584
# auc test 0.8446612748043963
# Mean auc test:  0.8400724154028156

# %%
test = data[data['combiner'] == 'y']

# %%
train.head()
# Out:
#    %AverageUtilCCard  %AvgUtilOfCCards1Yr  %AvgUtilOfCLines2Yrs  \
# 0            134.655                  NaN                   NaN
# 1            109.230             14584.29              11385.24
# 2                NaN                  NaN                   NaN
# 3            120.120                 0.00               8580.00
# 4            104.535             10326.45               8360.19
#
#    %AvgUtilOfCLines6MoMiss1  %UtilCLinesonAutoLoan  %UtilCLinesonEduLoan  \
# 0                   134.655                    NaN                   NaN
# 1                    86.685                    NaN                   NaN
# 2                       NaN                    NaN              149.6805
# 3                    85.800                    NaN                   NaN
# 4                   115.335                    NaN              150.0135
#
#    AnnualIncome  AnnualPaidPreviousYearAllCards   Applicant_ID  \
# 0      96375139                       7875694.0  Apcnt_1000000
# 1      28141427                       2141445.0  Apcnt_1000004
# 2      16576457                             0.0  Apcnt_1000008
# 3      48187375                       1186839.0  Apcnt_1000012
# 4      28141427                        511535.0  Apcnt_1000016
#
#    AvgTenureofActiveRevolveCardsinDays  ...  SumTenureonActiveCLinesinMonth  \
# 0                               4000.5  ...                          8.0000
# 1                               4161.0  ...                         17.5000
# 2                               1597.5  ...                          0.6666
# 3                               1701.0  ...                          7.8334
# 4                               1551.0  ...                          1.0000
#
#    TenureofOldestCCardsinDays  TenureofOldestCLineinDays  \
# 0                     17064.0                    17064.0
# 1                     13413.0                    13413.0
# 2                      4746.0                    15696.0
# 3                      4014.0                    11679.0
# 4                      3285.0                    19437.0
#
#    TenureofOldestRevolveCCardsinDays  TotalCreditAvailActivelines  \
# 0                            11376.0                   11333126.0
# 1                             8942.0                    2533168.0
# 2                             3164.0                    1079864.0
# 3                             2676.0                    3621979.0
# 4                             2190.0                     361770.0
#
#    TotalDueActiveCards  combiner  default_status  form_field48  form_field49
# 0            2301324.0         x               0           NaN      1.129518
# 1            3982971.0         x               0    349.805730      1.620483
# 2                  NaN         x               1           NaN      1.513370
# 3             771776.0         x               0     89.940100      0.664452
# 4             818456.0         x               0     97.887502      1.427891
#
# [5 rows x 53 columns]

# %%
import lightgbm as lgb

#fitting the model

lgb_model.fit(train.drop(['default_status','combiner', 'Applicant_ID'], axis = 1), target['default_status'].ravel())


#Test set predictions

test['default_status']  = lgb_model.predict_proba(test.drop(['default_status', 'combiner', 'Applicant_ID'],\
                                                            axis = 1))[:,1]

# %%
test['default_status'].head()
# Out:
# 56000    0.326519
# 56001    0.381663
# 56002    0.371663
# 56003    0.743934
# 56004    0.119414
# Name: default_status, dtype: float64

# %% [markdown]
# #### Exploring feature importance

# %%
lgb.plot_importance(lgb_model, importance_type = "gain")

# %%
zip_imp = zip(lgb_model.feature_importances_, train.drop(['default_status','combiner', 'Applicant_ID'], axis = 1).columns)

# %%
feat_imp = list(zip_imp)

# %%
feat_imp.sort(reverse = True)

# %%
feat_imp
# Out:
# [(2388, 'CreditEnquiredRisk'),
#  (2024, 'Creditworth_score'),
#  (1149, 'PropertyMarketValue'),
#  (1013, 'ProductType'),
#  (951, 'MaxTenureonAutoLoansinDays'),
#  (946, 'RatioDueCCLinesMaxSumCCLines'),
#  (927, 'SumTenureonActiveCLinesinMonth'),
#  (874, 'PostDefaultDuesCollectedA500'),
#  (859, 'TenureofOldestCLineinDays'),
#  (849, 'MaxCreditAvailActivelines'),
#  (849, 'FinanceStressIndex'),
#  (823, '%AvgUtilOfCLines6MoMiss1'),
#  (801, 'AnnualPaidPreviousYearAllCards'),
#  (747, 'MaxTenureonEduLoansinDays'),
#  (741, 'RatioDueCCLinesMinSumCCLines'),
#  (740, 'TotalDueActiveCards'),
#  (731, 'MinCreditAvailAfterPaymentsCards'),
#  (723, 'SumOfAvailCreditOnCardsMissed1Pay'),
#  (721, 'TenureofOldestCCardsinDays'),
#  (713, 'LoanDefaultSeverityAll'),
#  (698, 'AvgTenureofActiveRevolveCardsinDays'),
#  (688, '%AverageUtilCCard'),
#  (686, 'TenureofOldestRevolveCCardsinDays'),
#  (627, 'MaxCreditAvailAfterPaymentsCards'),
#  (617, 'NumberCLinesPaidHighRisk'),
#  (613, '%UtilCLinesonEduLoan'),
#  (608, 'NumActiveCLines'),
#  (586, 'SumTenureonActiveCCardsinMonth'),
#  (569, 'form_field49'),
#  (554, 'NumCCardsActiveTenure2Yrs'),
#  (548, 'form_field48'),
#  (543, 'TotalCreditAvailActivelines'),
#  (534, 'NumOfCLineslast6MoMiss1'),
#  (531, '%UtilCLinesonAutoLoan'),
#  (524, 'AnnualIncome'),
#  (523, '%AvgUtilOfCCards1Yr'),
#  (507, '%AvgUtilOfCLines2Yrs'),
#  (458, 'NumActivatedCLinesinlast2Yrs'),
#  (403, 'LoanDefaultSeverityEdu'),
#  (402, 'NumOfMortgageLoansMissed2x'),
#  (332, 'LoanDefaultSeverityAuto'),
#  (297, 'NumActiveCCards75pCreditUsed'),
#  (284, 'NumActiveCLinesFullCreditUsed'),
#  (272, 'NumDaysonlastmissedCLine'),
#  (243, 'NumOfRevolveCCardslast2YrMiss1'),
#  (227, 'NumOfAutoLoansMissed2x'),
#  (217, 'NumActiveCLines75pCreditUsed'),
#  (175, 'NumActiveCCardsFullCreditUsed'),
#  (122, 'NumActiveCCardsRenewedFullCreditUsed'),
#  (43, 'NumActiveCLinesDeliquent')]

# %% [markdown]
# #### LightGBM Baseline score 0.842
# #### EDA Continued:

# %%
data['ProductType'] = labstat.inverse_transform(data['ProductType'])

# %%
data.isnull().sum() / len(data)

# %% [markdown]
# #### Feature Relationships with Default Status

# %%
data.columns

# %% [markdown]
# #### Create Baseline Submission

# %%
submission.head()

# %%
sub_test = test[['Applicant_ID', 'default_status']]

# %%
sub_test.reset_index(drop = True, inplace = True)

# %%
sub_test.to_csv("baseline submission 5.csv", index = False)

# %%
sub_test
