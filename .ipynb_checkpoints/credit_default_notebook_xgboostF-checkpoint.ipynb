# %%
#Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import matplotlib.gridspec as gridspec
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
test = pd.read_csv("test.csv", sep=',',index_col=[0])
train = pd.read_csv("train.csv", sep = ',',index_col=[0])
submission = pd.read_csv("submission.csv", sep=',',index_col=[0])

# %%
test.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000032       3236.0      0.34875      10.2006       0.0000
# 1  Apcnt_1000048       3284.0      1.27360       2.9606       9.0198
# 2  Apcnt_1000052          NaN      0.27505       0.0600       0.0000
# 3  Apcnt_1000076       3232.0      0.28505       2.8032       0.0000
# 4  Apcnt_1000080       3466.0      2.09545       0.8318       2.5182
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0          0.0     418564.0     418564.0     418564.0     540710.0  ...
# 1          0.0          0.0    9858816.0      49014.0    1510098.0  ...
# 2          0.0          NaN          NaN          NaN          NaN  ...
# 3          0.0          0.0     473802.0     473802.0    1724437.0  ...
# 4          0.0      19839.0    1150662.0    1150662.0    7860523.0  ...
#
#    form_field41  form_field42  form_field43  form_field44  form_field45  \
# 0           NaN      0.825000          1.01      0.800000           NaN
# 1       18.8415      0.507694          4.04      0.623248           1.0
# 2           NaN           NaN          0.00           NaN           NaN
# 3           NaN      0.916663          2.02      0.464224           NaN
# 4           NaN      0.234047         23.23      0.726688           0.0
#
#    form_field46  form_field47  form_field48  form_field49  form_field50
# 0           0.0        charge           NaN      0.000000      0.011221
# 1           0.0       lending           NaN      0.504974      0.043525
# 2           NaN        charge           NaN      0.000000           NaN
# 3           NaN        charge     90.163742      0.788809      0.104029
# 4           0.0       lending   1303.587148      1.637733      0.163124
#
# [5 rows x 51 columns]

# %%
#train.dtypes

# %%
test.to_csv('test.csv')
train.to_csv('train.csv')
submission.to_csv('submission.csv')

# %%
#train.head().T

# %%
# Convert ff47 and ff50 categorical variables to 0 and 1
new_train = pd.get_dummies(train, columns=['form_field47','default_status'])

# %%
# Drop duplicate columns
train_drop = new_train.drop(['form_field47_lending','default_status_yes'], axis=1)

# %%
# Rename the columns
train_rename = train_drop.rename(columns = {"form_field1":'Creditworthiness_score',"form_field2":'CreditEnquiredRisk',
                                            "form_field3":'LoanDefaultSeverityAll',"form_field4":'LoanDefaultSeverityAuto',
                                            "form_field5":'LoanDefaultSeverityEdu',"form_field6":'MinCreditAvailAfterPayments',
                                            "form_field7":'MaxCreditAvailActiveAll',"form_field8":'MaxCreditAvailAfterPayments',"form_field9":'SumOfAvailCreditMissed1Pay',
                                            "form_field10":'TotalCreditAvailActiveAll',"form_field11":'PostDefaultDuesCollectedA500',
                                            "form_field12":'TotalDueActive',"form_field13":'AllAnnualPaidPreviousYear',
                                            "form_field14":'AnnualIncome',"form_field15":'PropertyMarketValue',
                                            "form_field16":'NumActiveCCardsPaidOffFullCreditUsed',"form_field17":'NumActiveCCardsFullCreditUsed',
                                            "form_field18":'NumActiveFullCLinesFullCreditUsed',"form_field19":'NumActiveCCards75pCreditUsed',
                                            "form_field20":'NumActiveCLines75pCreditUsed',"form_field21":'%AverageUseOfCCardLoans',
                                            "form_field22":'%AverageUseOfCLines2Yrs',"form_field23":'%AverageUseOfCCards1Yr',
                                            "form_field24":'%AverageUseOfCLines6MoMiss1',"form_field25":'AverageTenureofActiveRevolveCardsinDays',
                                            "form_field26":'TenureofOldestCCardsinDays',"form_field27":'TenureofOldestRevolvingCCardsinDays',
                                            "form_field28":'NumOfDaysonlastmissedCLine',"form_field29":'TenureofOldestCLineinDays',
                                            "form_field30":'MaxTenureonAutoLoansinDays',"form_field31":'MaxTenureonEduLoansinDays',
                                            "form_field32":'SumTenureonActiveCCardsinMonth',"form_field33":'SumTenureonActiveCLinesinMonth',
                                            "form_field34":'NumOfCLineslast6MoMiss1', "form_field35":'NumOfRevolveCCardslast2YrMiss1',
                                            "form_field36":'NumActiveCLines',"form_field37":'NumCCardsActiveTenure2Yrs',
                                            "form_field38":'ActivatedCLinesinlast2Yrs',"form_field39":'NumActiveCLinesDeliquent',
                                            "form_field40":'%UseCLinesonEduLoan',"form_field41":'%UseCLinesonAutoLoan',
                                            "form_field42":'FinanceStressIndex',"form_field43":'NumberCLinesPaidHighRisk',
                                            "form_field44":'DebtRatio1Max',"form_field45":'NumOfHomeLoansMissed2x',
                                            "form_field46":'NumOfAutoLoansMissed2x',"form_field50":'DebtRatio1Min',
                                            'form_field47_charge': 'ProductApplicatn', 'default_status_no': 'default_status'}, inplace = False)

# %%
# Begin cleaning process
#Fill with mean
train_rename['Creditworthiness_score'] = train_rename['Creditworthiness_score'].fillna(train_rename['Creditworthiness_score'].mean())

# %%
train_final = train_rename

# %%
train_final.fillna(0, inplace=True)

# %%
train_final.shape
# Out:
# (56000, 52)

# %%
#train_rename.tail(20)

# %%
#train_rename['Creditworthiness_score'] = pd.to_numeric(train_rename['Creditworthiness_score'], errors='coerce')

# %%
#train_rename.isnull().sum() #Investigate each variable to determine what to do with the null values

# %%
#train_rename.isnull()==True

# %%
#Exploratory data analysis
train_rename.describe().T
# Out:
#                                            count          mean           std  \
# Creditworthiness_score                   56000.0  3.491796e+03  1.841576e+02
# CreditEnquiredRisk                       56000.0  5.129327e-01  8.044449e-01
# LoanDefaultSeverityAll                   56000.0  1.045555e+00  2.142577e+00
# LoanDefaultSeverityAuto                  56000.0  8.465780e-01  3.148393e+00
# LoanDefaultSeverityEdu                   56000.0  1.943915e+00  1.048017e+01
# MinCreditAvailAfterPayments              56000.0  4.754725e+05  1.278801e+06
# MaxCreditAvailActiveAll                  56000.0  6.232263e+06  1.833213e+07
# MaxCreditAvailAfterPayments              56000.0  2.000037e+06  3.605225e+06
# SumOfAvailCreditMissed1Pay               56000.0  1.127813e+07  1.888150e+07
# TotalCreditAvailActiveAll                56000.0  1.178069e+07  2.662648e+07
# PostDefaultDuesCollectedA500             56000.0  9.018363e+05  3.410812e+06
# TotalDueActive                           56000.0  2.281467e+06  4.257095e+06
# AllAnnualPaidPreviousYear                56000.0  5.377934e+06  2.217336e+07
# AnnualIncome                             56000.0  6.914875e+07  2.713995e+09
# PropertyMarketValue                      56000.0  6.854913e+07  1.054534e+08
# NumActiveCCardsPaidOffFullCreditUsed     56000.0  1.767857e-01  5.533038e-01
# NumActiveCCardsFullCreditUsed            56000.0  2.127857e-01  6.531910e-01
# NumActiveFullCLinesFullCreditUsed        56000.0  2.213393e-01  6.630818e-01
# NumActiveCCards75pCreditUsed             56000.0  9.487321e-01  1.736411e+00
# NumActiveCLines75pCreditUsed             56000.0  1.025054e+00  1.781337e+00
# %AverageUseOfCCardLoans                  56000.0  6.201150e+01  5.971897e+01
# %AverageUseOfCLines2Yrs                  56000.0  4.213715e+03  5.526982e+03
# %AverageUseOfCCards1Yr                   56000.0  3.212264e+03  5.177919e+03
# %AverageUseOfCLines6MoMiss1              56000.0  7.973147e+01  3.839055e+02
# AverageTenureofActiveRevolveCardsinDays  56000.0  2.369130e+03  2.021841e+03
# TenureofOldestCCardsinDays               56000.0  8.764188e+03  8.880612e+03
# TenureofOldestRevolvingCCardsinDays      56000.0  5.162560e+03  5.435350e+03
# NumOfDaysonlastmissedCLine               56000.0  1.716481e+04  2.688023e+04
# TenureofOldestCLineinDays                56000.0  1.641382e+04  9.724279e+03
# MaxTenureonAutoLoansinDays               56000.0  2.838520e+03  3.472208e+03
# MaxTenureonEduLoansinDays                56000.0  3.216942e+03  5.951728e+03
# SumTenureonActiveCCardsinMonth           56000.0  8.470242e+02  1.030698e+03
# SumTenureonActiveCLinesinMonth           56000.0  1.361423e+01  1.517762e+01
# NumOfCLineslast6MoMiss1                  56000.0  2.287857e-01  6.811396e-01
# NumOfRevolveCCardslast2YrMiss1           56000.0  1.172500e-01  4.505223e-01
# NumActiveCLines                          56000.0  1.240096e+01  1.069991e+01
# NumCCardsActiveTenure2Yrs                56000.0  7.655107e+00  9.212766e+00
# ActivatedCLinesinlast2Yrs                56000.0  8.546893e+00  7.973194e+00
# NumActiveCLinesDeliquent                 56000.0  8.401786e-02  4.082599e-01
# %UseCLinesonEduLoan                      56000.0  3.238623e+01  6.467777e+01
# %UseCLinesonAutoLoan                     56000.0  3.430989e+01  5.441791e+01
# FinanceStressIndex                       56000.0  3.595164e-01  4.117676e-01
# NumberCLinesPaidHighRisk                 56000.0  6.567218e+00  6.381235e+00
# DebtRatio1Max                            56000.0  5.092222e-01  2.502918e-01
# NumOfHomeLoansMissed2x                   56000.0  3.196429e-02  1.966152e-01
# NumOfAutoLoansMissed2x                   56000.0  6.828571e-02  2.868847e-01
# form_field48                             56000.0  1.913831e+05  1.313048e+06
# form_field49                             56000.0  1.042410e+00  1.802351e+00
# DebtRatio1Min                            56000.0  4.820133e+05  5.239443e+06
# ProductApplicatn                         56000.0  6.495179e-01  4.771252e-01
# default_status                           56000.0  7.550893e-01  4.300381e-01
#
#                                             min           25%           50%  \
# Creditworthiness_score                   2990.0  3.366000e+03  3.491796e+03
# CreditEnquiredRisk                          0.0  4.770000e-02  2.267000e-01
# LoanDefaultSeverityAll                      0.0  0.000000e+00  6.000000e-02
# LoanDefaultSeverityAuto                     0.0  0.000000e+00  0.000000e+00
# LoanDefaultSeverityEdu                      0.0  0.000000e+00  0.000000e+00
# MinCreditAvailAfterPayments                 0.0  0.000000e+00  4.006700e+04
# MaxCreditAvailActiveAll                     0.0  3.248150e+05  2.174704e+06
# MaxCreditAvailAfterPayments                 0.0  0.000000e+00  3.765520e+05
# SumOfAvailCreditMissed1Pay                  0.0  4.217732e+05  3.712227e+06
# TotalCreditAvailActiveAll                   0.0  4.170080e+05  3.641234e+06
# PostDefaultDuesCollectedA500                0.0  0.000000e+00  0.000000e+00
# TotalDueActive                              0.0  1.205900e+04  7.037010e+05
# AllAnnualPaidPreviousYear                   0.0  0.000000e+00  1.160776e+06
# AnnualIncome                                0.0  1.657646e+07  2.814143e+07
# PropertyMarketValue                         0.0  0.000000e+00  3.854990e+07
# NumActiveCCardsPaidOffFullCreditUsed        0.0  0.000000e+00  0.000000e+00
# NumActiveCCardsFullCreditUsed               0.0  0.000000e+00  0.000000e+00
# NumActiveFullCLinesFullCreditUsed           0.0  0.000000e+00  0.000000e+00
# NumActiveCCards75pCreditUsed                0.0  0.000000e+00  0.000000e+00
# NumActiveCLines75pCreditUsed                0.0  0.000000e+00  0.000000e+00
# %AverageUseOfCCardLoans                     0.0  0.000000e+00  5.077500e+01
# %AverageUseOfCLines2Yrs                     0.0  0.000000e+00  5.963625e+02
# %AverageUseOfCCards1Yr                      0.0  0.000000e+00  0.000000e+00
# %AverageUseOfCLines6MoMiss1                 0.0  0.000000e+00  2.983500e+01
# AverageTenureofActiveRevolveCardsinDays     0.0  8.895000e+02  1.987500e+03
# TenureofOldestCCardsinDays                  0.0  1.734000e+03  6.480000e+03
# TenureofOldestRevolvingCCardsinDays         0.0  7.300000e+02  3.528000e+03
# NumOfDaysonlastmissedCLine                  0.0  6.000000e+01  4.260000e+02
# TenureofOldestCLineinDays                   0.0  9.672000e+03  1.496400e+04
# MaxTenureonAutoLoansinDays                  0.0  0.000000e+00  6.700000e+02
# MaxTenureonEduLoansinDays                   0.0  0.000000e+00  0.000000e+00
# SumTenureonActiveCCardsinMonth              0.0  1.120000e+02  4.880000e+02
# SumTenureonActiveCLinesinMonth              0.0  2.166600e+00  7.333400e+00
# NumOfCLineslast6MoMiss1                     0.0  0.000000e+00  0.000000e+00
# NumOfRevolveCCardslast2YrMiss1              0.0  0.000000e+00  0.000000e+00
# NumActiveCLines                             0.0  6.000000e+00  1.000000e+01
# NumCCardsActiveTenure2Yrs                   0.0  0.000000e+00  4.000000e+00
# ActivatedCLinesinlast2Yrs                   0.0  4.000000e+00  6.000000e+00
# NumActiveCLinesDeliquent                    0.0  0.000000e+00  0.000000e+00
# %UseCLinesonEduLoan                         0.0  0.000000e+00  0.000000e+00
# %UseCLinesonAutoLoan                        0.0  0.000000e+00  0.000000e+00
# FinanceStressIndex                          0.0  0.000000e+00  2.062500e-01
# NumberCLinesPaidHighRisk                    0.0  2.020000e+00  5.050000e+00
# DebtRatio1Max                               0.0  3.491480e-01  5.480800e-01
# NumOfHomeLoansMissed2x                      0.0  0.000000e+00  0.000000e+00
# NumOfAutoLoansMissed2x                      0.0  0.000000e+00  0.000000e+00
# form_field48                                0.0  0.000000e+00  5.141139e+01
# form_field49                                0.0  0.000000e+00  0.000000e+00
# DebtRatio1Min                               0.0  7.502524e-03  9.600000e-02
# ProductApplicatn                            0.0  0.000000e+00  1.000000e+00
# default_status                              0.0  1.000000e+00  1.000000e+00
#
#                                                   75%           max
# Creditworthiness_score                   3.610000e+03  3.900000e+03
# CreditEnquiredRisk                       6.757000e-01  1.801505e+01
# LoanDefaultSeverityAll                   1.270800e+00  5.737160e+01
# LoanDefaultSeverityAuto                  0.000000e+00  9.167220e+01
# LoanDefaultSeverityEdu                   0.000000e+00  4.077486e+02
# MinCreditAvailAfterPayments              3.023502e+05  5.313546e+07
# MaxCreditAvailActiveAll                  6.335740e+06  2.158794e+09
# MaxCreditAvailAfterPayments              2.361230e+06  1.037397e+08
# SumOfAvailCreditMissed1Pay               1.403308e+07  3.200533e+08
# TotalCreditAvailActiveAll                1.315909e+07  2.191361e+09
# PostDefaultDuesCollectedA500             5.173700e+05  1.707430e+08
# TotalDueActive                           2.677098e+06  1.240439e+08
# AllAnnualPaidPreviousYear                4.779254e+06  2.457824e+09
# AnnualIncome                             4.818738e+07  3.854990e+11
# PropertyMarketValue                      9.949881e+07  3.456119e+09
# NumActiveCCardsPaidOffFullCreditUsed     0.000000e+00  1.100000e+01
# NumActiveCCardsFullCreditUsed            0.000000e+00  2.100000e+01
# NumActiveFullCLinesFullCreditUsed        0.000000e+00  2.100000e+01
# NumActiveCCards75pCreditUsed             1.000000e+00  2.800000e+01
# NumActiveCLines75pCreditUsed             1.000000e+00  2.900000e+01
# %AverageUseOfCCardLoans                  1.152900e+02  1.957875e+03
# %AverageUseOfCLines2Yrs                  8.220101e+03  9.720000e+04
# %AverageUseOfCCards1Yr                   5.495734e+03  9.720000e+04
# %AverageUseOfCLines6MoMiss1              9.687000e+01  3.186375e+04
# AverageTenureofActiveRevolveCardsinDays  3.330000e+03  2.509350e+04
# TenureofOldestCCardsinDays               1.277400e+04  7.327500e+04
# TenureofOldestRevolvingCCardsinDays      7.666000e+03  4.252200e+04
# NumOfDaysonlastmissedCLine               6.077200e+04  6.077200e+04
# TenureofOldestCLineinDays                2.171700e+04  7.391400e+04
# MaxTenureonAutoLoansinDays               6.022000e+03  2.555000e+04
# MaxTenureonEduLoansinDays                4.746000e+03  4.708500e+04
# SumTenureonActiveCCardsinMonth           1.230000e+03  2.130600e+04
# SumTenureonActiveCLinesinMonth           2.083340e+01  1.520000e+02
# NumOfCLineslast6MoMiss1                  0.000000e+00  2.100000e+01
# NumOfRevolveCCardslast2YrMiss1           0.000000e+00  1.000000e+01
# NumActiveCLines                          1.600000e+01  2.000000e+02
# NumCCardsActiveTenure2Yrs                1.200000e+01  1.060000e+02
# ActivatedCLinesinlast2Yrs                1.200000e+01  1.560000e+02
# NumActiveCLinesDeliquent                 0.000000e+00  2.100000e+01
# %UseCLinesonEduLoan                      0.000000e+00  6.454500e+02
# %UseCLinesonAutoLoan                     7.999987e+01  2.550000e+02
# FinanceStressIndex                       6.111160e-01  2.200000e+00
# NumberCLinesPaidHighRisk                 1.010000e+01  9.191000e+01
# DebtRatio1Max                            7.394740e-01  8.000000e-01
# NumOfHomeLoansMissed2x                   0.000000e+00  5.000000e+00
# NumOfAutoLoansMissed2x                   0.000000e+00  5.000000e+00
# form_field48                             5.096936e+02  5.321014e+07
# form_field49                             1.158480e+00  2.800000e+01
# DebtRatio1Min                            3.800000e-01  2.307571e+08
# ProductApplicatn                         1.000000e+00  1.000000e+00
# default_status                           1.000000e+00  1.000000e+00

# %%
#train_rename.head(20)

# %%
train_rename['default_status'].value_counts(normalize=True)
# Out:
# 1    0.755089
# 0    0.244911
# Name: default_status, dtype: float64

# %%
#train_rename.info()

# %%
#Fill with mode
#cols = ['LoanDefaultSeverityAll','LoanDefaultSeverityAuto', 'LoanDefaultSeverityEdu']
#train_rename['LoanDefaultSeverityAll'] = train_rename['LoanDefaultSeverityAll'].fillna(train_rename['LoanDefaultSeverityAll'].mode()[0])
#train_rename['LoanDefaultSeverityAuto'].fillna(train_rename['LoanDefaultSeverityAuto'].mode()[0])
#train_rename['LoanDefaultSeverityEdu'].fillna(train_rename['LoanDefaultSeverityEdu'].mode()[0])

#Fill with zero
#train_rename[cols]=train_rename.filter(cols).fillna(mode.iloc[0])

# %%
train_feature = train_final.drop(['Applicant_ID'], axis=1)

# %% [markdown]
# ## Model

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, precision_recall_curve, f1_score
from sklearn.decomposition import PCA
from sklearn import linear_model
from sklearn.pipeline import Pipeline

# %%
#Values for predictor, dropping off the target
X = train_feature.drop(['default_status'], axis=1)

#Values for target
y = train_feature['default_status'].values # y is output (or dependent) variable

# Standardize the data
X = MinMaxScaler().fit_transform(X)

# %%
number_features = len(train_feature.columns)

# %%
number_features
# Out:
# 51

# %%
pca=PCA()                                    
pca.fit(X)
# Out:
# PCA()

# %%
PCA(copy=True, n_components=None, whiten=False)
pca.components_
# Out:
# array([[ 2.62910553e-01, -1.61427293e-02, -2.28869782e-02, ...,
#         -1.88229635e-02,  5.15398174e-03, -6.72717742e-01],
#        [-1.81385333e-01,  8.10018572e-03,  1.74571125e-02, ...,
#          7.42350536e-03,  2.10103247e-04, -7.33732974e-01],
#        [-4.21082228e-02,  4.85383568e-03,  4.51581349e-03, ...,
#          2.76014086e-02, -2.13003495e-04, -3.36996827e-02],
#        ...,
#        [-3.63400181e-03,  3.03808285e-03, -2.88537202e-02, ...,
#         -4.24748083e-02, -2.09223121e-03,  4.46234256e-06],
#        [ 5.10788082e-04, -1.87654067e-04, -3.56807563e-04, ...,
#         -3.03804184e-03, -1.12920587e-03, -2.11183715e-06],
#        [ 1.97893771e-03,  7.01736045e-04, -5.01194304e-04, ...,
#          9.80235879e-04, -1.78694872e-03,  3.72173511e-05]])

# %%
pca.explained_variance_ratio_
# Out:
# array([3.55553640e-01, 2.16654769e-01, 1.20570185e-01, 7.35721549e-02,
#        5.69794096e-02, 2.81008787e-02, 2.64890206e-02, 2.02603726e-02,
#        1.80011642e-02, 1.07516786e-02, 9.26841620e-03, 8.00662588e-03,
#        7.19673433e-03, 6.16416647e-03, 4.79225219e-03, 4.59531099e-03,
#        4.21638933e-03, 3.47041752e-03, 2.65525449e-03, 2.21939117e-03,
#        2.10061238e-03, 2.03304037e-03, 1.83427834e-03, 1.70399468e-03,
#        1.42705873e-03, 1.20051377e-03, 1.10750388e-03, 1.07269338e-03,
#        9.95845885e-04, 9.02326351e-04, 8.08765331e-04, 6.73561783e-04,
#        6.28994380e-04, 5.89596565e-04, 5.68396103e-04, 4.63233470e-04,
#        3.90585351e-04, 3.79594037e-04, 2.63183692e-04, 2.32712249e-04,
#        2.17818213e-04, 1.91555003e-04, 1.77090999e-04, 1.63702030e-04,
#        1.41548683e-04, 7.62677620e-05, 6.05412627e-05, 5.88535340e-05,
#        1.03220717e-05, 7.57848414e-06])

# %%
pca.explained_variance_
# Out:
# array([2.90969414e-01, 1.77300705e-01, 9.86693200e-02, 6.02082059e-02,
#        4.66294352e-02, 2.29965195e-02, 2.16774459e-02, 1.65801951e-02,
#        1.47313586e-02, 8.79869941e-03, 7.58486294e-03, 6.55226940e-03,
#        5.88948989e-03, 5.04448190e-03, 3.92176778e-03, 3.76059979e-03,
#        3.45050702e-03, 2.84003660e-03, 2.17294314e-03, 1.81625182e-03,
#        1.71904850e-03, 1.66375055e-03, 1.50109247e-03, 1.39447407e-03,
#        1.16784191e-03, 9.82447507e-04, 9.06332316e-04, 8.77844943e-04,
#        8.14956340e-04, 7.38424079e-04, 6.61857868e-04, 5.51213249e-04,
#        5.14741252e-04, 4.82499818e-04, 4.65150296e-04, 3.79089836e-04,
#        3.19637821e-04, 3.10643014e-04, 2.15377923e-04, 1.90441439e-04,
#        1.78252817e-04, 1.56760164e-04, 1.44923462e-04, 1.33966520e-04,
#        1.15837198e-04, 6.24141718e-05, 4.95442986e-05, 4.81631359e-05,
#        8.44712814e-06, 6.20189709e-06])

# %%
variance = np.cumsum(np.round(pca.explained_variance_ratio_, decimals=3)*100)
variance
# Out:
# array([35.6, 57.3, 69.4, 76.8, 82.5, 85.3, 87.9, 89.9, 91.7, 92.8, 93.7,
#        94.5, 95.2, 95.8, 96.3, 96.8, 97.2, 97.5, 97.8, 98. , 98.2, 98.4,
#        98.6, 98.8, 98.9, 99. , 99.1, 99.2, 99.3, 99.4, 99.5, 99.6, 99.7,
#        99.8, 99.9, 99.9, 99.9, 99.9, 99.9, 99.9, 99.9, 99.9, 99.9, 99.9,
#        99.9, 99.9, 99.9, 99.9, 99.9, 99.9])

# %%
plt.ylabel('% Cumulative Variance')
plt.xlabel('Principal Componenet')
plt.title('PCA Analysis')
plt.ylim(30,100.5)
plt.style.context('seaborn-whitegrid')


plt.plot(variance)

# %%
pca = PCA(n_components=10)
X_r = pca.fit(X).transform(X)
import xgboost as xgb
model=xgb.XGBClassifier(random_state=1,learning_rate=0.01)
pipeline = Pipeline(steps=[('pca', pca), ('model', model)])

# %%
#import xgboost as xgb
#model=xgb.XGBClassifier(random_state=1,learning_rate=0.01)
#model.fit(X_train, y_train

# %%
#Train Test split 

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, stratify=y
                                                   , random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((44800, 50), (11200, 50), (44800,), (11200,))

# %%
pipeline.fit(X_train, y_train) # Add solver='lbfgs' to get rid of the deprecation warning
# Out:
# Pipeline(steps=[('pca', PCA(n_components=10)),
#                 ('model', XGBClassifier(learning_rate=0.01, random_state=1))])

# %%
y_pred = pipeline.predict(X_test)

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.7903571428571429

# %%
f1_score(y_test, y_pred, average='micro')
# Out:
# 0.790357142857143

# %% [markdown]
# ## Test Data

# %%
test_rename = test.rename(columns = {"form_field1":'Creditworthiness_score',"form_field2":'CreditEnquiredRisk',
                                            "form_field3":'LoanDefaultSeverityAll',"form_field4":'LoanDefaultSeverityAuto',
                                            "form_field5":'LoanDefaultSeverityEdu',"form_field6":'MinCreditAvailAfterPayments',
                                            "form_field7":'MaxCreditAvailActiveAll',"form_field8":'MaxCreditAvailAfterPayments',"form_field9":'SumOfAvailCreditMissed1Pay',
                                            "form_field10":'TotalCreditAvailActiveAll',"form_field11":'PostDefaultDuesCollectedA500',
                                            "form_field12":'TotalDueActive',"form_field13":'AllAnnualPaidPreviousYear',
                                            "form_field14":'AnnualIncome',"form_field15":'PropertyMarketValue',
                                            "form_field16":'NumActiveCCardsPaidOffFullCreditUsed',"form_field17":'NumActiveCCardsFullCreditUsed',
                                            "form_field18":'NumActiveFullCLinesFullCreditUsed',"form_field19":'NumActiveCCards75pCreditUsed',
                                            "form_field20":'NumActiveCLines75pCreditUsed',"form_field21":'%AverageUseOfCCardLoans',
                                            "form_field22":'%AverageUseOfCLines2Yrs',"form_field23":'%AverageUseOfCCards1Yr',
                                            "form_field24":'%AverageUseOfCLines6MoMiss1',"form_field25":'AverageTenureofActiveRevolveCardsinDays',
                                            "form_field26":'TenureofOldestCCardsinDays',"form_field27":'TenureofOldestRevolvingCCardsinDays',
                                            "form_field28":'NumOfDaysonlastmissedCLine',"form_field29":'TenureofOldestCLineinDays',
                                            "form_field30":'MaxTenureonAutoLoansinDays',"form_field31":'MaxTenureonEduLoansinDays',
                                            "form_field32":'SumTenureonActiveCCardsinMonth',"form_field33":'SumTenureonActiveCLinesinMonth',
                                            "form_field34":'NumOfCLineslast6MoMiss1', "form_field35":'NumOfRevolveCCardslast2YrMiss1',
                                            "form_field36":'NumActiveCLines',"form_field37":'NumCCardsActiveTenure2Yrs',
                                            "form_field38":'ActivatedCLinesinlast2Yrs',"form_field39":'NumActiveCLinesDeliquent',
                                            "form_field40":'%UseCLinesonEduLoan',"form_field41":'%UseCLinesonAutoLoan',
                                            "form_field42":'FinanceStressIndex',"form_field43":'NumberCLinesPaidHighRisk',
                                            "form_field44":'DebtRatio1Max',"form_field45":'NumOfHomeLoansMissed2x',
                                            "form_field46":'NumOfAutoLoansMissed2x',"form_field50":'DebtRatio1Min',
                                            'form_field47_charge': 'ProductApplicatn', 'default_status_no': 'default_status'}, inplace = False)

# %%
test_rename.head()
# Out:
#     Applicant_ID  Creditworthiness_score  CreditEnquiredRisk  \
# 0  Apcnt_1000032                  3236.0             0.34875
# 1  Apcnt_1000048                  3284.0             1.27360
# 2  Apcnt_1000052                     NaN             0.27505
# 3  Apcnt_1000076                  3232.0             0.28505
# 4  Apcnt_1000080                  3466.0             2.09545
#
#    LoanDefaultSeverityAll  LoanDefaultSeverityAuto  LoanDefaultSeverityEdu  \
# 0                 10.2006                   0.0000                     0.0
# 1                  2.9606                   9.0198                     0.0
# 2                  0.0600                   0.0000                     0.0
# 3                  2.8032                   0.0000                     0.0
# 4                  0.8318                   2.5182                     0.0
#
#    MinCreditAvailAfterPayments  MaxCreditAvailActiveAll  \
# 0                     418564.0                 418564.0
# 1                          0.0                9858816.0
# 2                          NaN                      NaN
# 3                          0.0                 473802.0
# 4                      19839.0                1150662.0
#
#    MaxCreditAvailAfterPayments  SumOfAvailCreditMissed1Pay  ...  \
# 0                     418564.0                    540710.0  ...
# 1                      49014.0                   1510098.0  ...
# 2                          NaN                         NaN  ...
# 3                     473802.0                   1724437.0  ...
# 4                    1150662.0                   7860523.0  ...
#
#    %UseCLinesonAutoLoan  FinanceStressIndex  NumberCLinesPaidHighRisk  \
# 0                   NaN            0.825000                      1.01
# 1               18.8415            0.507694                      4.04
# 2                   NaN                 NaN                      0.00
# 3                   NaN            0.916663                      2.02
# 4                   NaN            0.234047                     23.23
#
#    DebtRatio1Max  NumOfHomeLoansMissed2x  NumOfAutoLoansMissed2x  \
# 0       0.800000                     NaN                     0.0
# 1       0.623248                     1.0                     0.0
# 2            NaN                     NaN                     NaN
# 3       0.464224                     NaN                     NaN
# 4       0.726688                     0.0                     0.0
#
#    form_field47  form_field48  form_field49  DebtRatio1Min
# 0        charge           NaN      0.000000       0.011221
# 1       lending           NaN      0.504974       0.043525
# 2        charge           NaN      0.000000            NaN
# 3        charge     90.163742      0.788809       0.104029
# 4       lending   1303.587148      1.637733       0.163124
#
# [5 rows x 51 columns]

# %%
# Convert ff47 and ff50 categorical variables to 0 and 1
new_test = pd.get_dummies(test, columns=['form_field47'])

# %%
# Drop duplicate columns
test_drop = new_test.drop(['form_field47_lending'], axis=1)

# %%
# Rename the columns
test_rename = test_drop.rename(columns = {"form_field1":'Creditworthiness_score',"form_field2":'CreditEnquiredRisk',
                                            "form_field3":'LoanDefaultSeverityAll',"form_field4":'LoanDefaultSeverityAuto',
                                            "form_field5":'LoanDefaultSeverityEdu',"form_field6":'MinCreditAvailAfterPayments',
                                            "form_field7":'MaxCreditAvailActiveAll',"form_field8":'MaxCreditAvailAfterPayments',"form_field9":'SumOfAvailCreditMissed1Pay',
                                            "form_field10":'TotalCreditAvailActiveAll',"form_field11":'PostDefaultDuesCollectedA500',
                                            "form_field12":'TotalDueActive',"form_field13":'AllAnnualPaidPreviousYear',
                                            "form_field14":'AnnualIncome',"form_field15":'PropertyMarketValue',
                                            "form_field16":'NumActiveCCardsPaidOffFullCreditUsed',"form_field17":'NumActiveCCardsFullCreditUsed',
                                            "form_field18":'NumActiveFullCLinesFullCreditUsed',"form_field19":'NumActiveCCards75pCreditUsed',
                                            "form_field20":'NumActiveCLines75pCreditUsed',"form_field21":'%AverageUseOfCCardLoans',
                                            "form_field22":'%AverageUseOfCLines2Yrs',"form_field23":'%AverageUseOfCCards1Yr',
                                            "form_field24":'%AverageUseOfCLines6MoMiss1',"form_field25":'AverageTenureofActiveRevolveCardsinDays',
                                            "form_field26":'TenureofOldestCCardsinDays',"form_field27":'TenureofOldestRevolvingCCardsinDays',
                                            "form_field28":'NumOfDaysonlastmissedCLine',"form_field29":'TenureofOldestCLineinDays',
                                            "form_field30":'MaxTenureonAutoLoansinDays',"form_field31":'MaxTenureonEduLoansinDays',
                                            "form_field32":'SumTenureonActiveCCardsinMonth',"form_field33":'SumTenureonActiveCLinesinMonth',
                                            "form_field34":'NumOfCLineslast6MoMiss1', "form_field35":'NumOfRevolveCCardslast2YrMiss1',
                                            "form_field36":'NumActiveCLines',"form_field37":'NumCCardsActiveTenure2Yrs',
                                            "form_field38":'ActivatedCLinesinlast2Yrs',"form_field39":'NumActiveCLinesDeliquent',
                                            "form_field40":'%UseCLinesonEduLoan',"form_field41":'%UseCLinesonAutoLoan',
                                            "form_field42":'FinanceStressIndex',"form_field43":'NumberCLinesPaidHighRisk',
                                            "form_field44":'DebtRatio1Max',"form_field45":'NumOfHomeLoansMissed2x',
                                            "form_field46":'NumOfAutoLoansMissed2x',"form_field50":'DebtRatio1Min',
                                            'form_field47_charge': 'ProductApplicatn', 'default_status_no': 'default_status'}, inplace = False)

# %%
test_rename.columns
# Out:
# Index(['Applicant_ID', 'Creditworthiness_score', 'CreditEnquiredRisk',
#        'LoanDefaultSeverityAll', 'LoanDefaultSeverityAuto',
#        'LoanDefaultSeverityEdu', 'MinCreditAvailAfterPayments',
#        'MaxCreditAvailActiveAll', 'MaxCreditAvailAfterPayments',
#        'SumOfAvailCreditMissed1Pay', 'TotalCreditAvailActiveAll',
#        'PostDefaultDuesCollectedA500', 'TotalDueActive',
#        'AllAnnualPaidPreviousYear', 'AnnualIncome', 'PropertyMarketValue',
#        'NumActiveCCardsPaidOffFullCreditUsed', 'NumActiveCCardsFullCreditUsed',
#        'NumActiveFullCLinesFullCreditUsed', 'NumActiveCCards75pCreditUsed',
#        'NumActiveCLines75pCreditUsed', '%AverageUseOfCCardLoans',
#        '%AverageUseOfCLines2Yrs', '%AverageUseOfCCards1Yr',
#        '%AverageUseOfCLines6MoMiss1',
#        'AverageTenureofActiveRevolveCardsinDays', 'TenureofOldestCCardsinDays',
#        'TenureofOldestRevolvingCCardsinDays', 'NumOfDaysonlastmissedCLine',
#        'TenureofOldestCLineinDays', 'MaxTenureonAutoLoansinDays',
#        'MaxTenureonEduLoansinDays', 'SumTenureonActiveCCardsinMonth',
#        'SumTenureonActiveCLinesinMonth', 'NumOfCLineslast6MoMiss1',
#        'NumOfRevolveCCardslast2YrMiss1', 'NumActiveCLines',
#        'NumCCardsActiveTenure2Yrs', 'ActivatedCLinesinlast2Yrs',
#        'NumActiveCLinesDeliquent', '%UseCLinesonEduLoan',
#        '%UseCLinesonAutoLoan', 'FinanceStressIndex',
#        'NumberCLinesPaidHighRisk', 'DebtRatio1Max', 'NumOfHomeLoansMissed2x',
#        'NumOfAutoLoansMissed2x', 'form_field48', 'form_field49',
#        'DebtRatio1Min', 'ProductApplicatn'],
#       dtype='object')

# %%
#Fill with mean
test_rename['Creditworthiness_score'] = test_rename['Creditworthiness_score'].fillna(test_rename['Creditworthiness_score'].mean())

# %%
test_rename.shape
# Out:
# (24000, 51)

# %%
#test_final = test_rename

# %%
test_rename.fillna(0, inplace=True)

# %%
test_rename.head()
# Out:
#     Applicant_ID  Creditworthiness_score  CreditEnquiredRisk  \
# 0  Apcnt_1000032             3236.000000             0.34875
# 1  Apcnt_1000048             3284.000000             1.27360
# 2  Apcnt_1000052             3492.284404             0.27505
# 3  Apcnt_1000076             3232.000000             0.28505
# 4  Apcnt_1000080             3466.000000             2.09545
#
#    LoanDefaultSeverityAll  LoanDefaultSeverityAuto  LoanDefaultSeverityEdu  \
# 0                 10.2006                   0.0000                     0.0
# 1                  2.9606                   9.0198                     0.0
# 2                  0.0600                   0.0000                     0.0
# 3                  2.8032                   0.0000                     0.0
# 4                  0.8318                   2.5182                     0.0
#
#    MinCreditAvailAfterPayments  MaxCreditAvailActiveAll  \
# 0                     418564.0                 418564.0
# 1                          0.0                9858816.0
# 2                          0.0                      0.0
# 3                          0.0                 473802.0
# 4                      19839.0                1150662.0
#
#    MaxCreditAvailAfterPayments  SumOfAvailCreditMissed1Pay  ...  \
# 0                     418564.0                    540710.0  ...
# 1                      49014.0                   1510098.0  ...
# 2                          0.0                         0.0  ...
# 3                     473802.0                   1724437.0  ...
# 4                    1150662.0                   7860523.0  ...
#
#    %UseCLinesonAutoLoan  FinanceStressIndex  NumberCLinesPaidHighRisk  \
# 0                0.0000            0.825000                      1.01
# 1               18.8415            0.507694                      4.04
# 2                0.0000            0.000000                      0.00
# 3                0.0000            0.916663                      2.02
# 4                0.0000            0.234047                     23.23
#
#    DebtRatio1Max  NumOfHomeLoansMissed2x  NumOfAutoLoansMissed2x  \
# 0       0.800000                     0.0                     0.0
# 1       0.623248                     1.0                     0.0
# 2       0.000000                     0.0                     0.0
# 3       0.464224                     0.0                     0.0
# 4       0.726688                     0.0                     0.0
#
#    form_field48  form_field49  DebtRatio1Min  ProductApplicatn
# 0      0.000000      0.000000       0.011221                 1
# 1      0.000000      0.504974       0.043525                 0
# 2      0.000000      0.000000       0.000000                 1
# 3     90.163742      0.788809       0.104029                 1
# 4   1303.587148      1.637733       0.163124                 0
#
# [5 rows x 51 columns]

# %%
test_rename.shape
# Out:
# (24000, 51)

# %%
train_feature.columns
# Out:
# Index(['Creditworthiness_score', 'CreditEnquiredRisk',
#        'LoanDefaultSeverityAll', 'LoanDefaultSeverityAuto',
#        'LoanDefaultSeverityEdu', 'MinCreditAvailAfterPayments',
#        'MaxCreditAvailActiveAll', 'MaxCreditAvailAfterPayments',
#        'SumOfAvailCreditMissed1Pay', 'TotalCreditAvailActiveAll',
#        'PostDefaultDuesCollectedA500', 'TotalDueActive',
#        'AllAnnualPaidPreviousYear', 'AnnualIncome', 'PropertyMarketValue',
#        'NumActiveCCardsPaidOffFullCreditUsed', 'NumActiveCCardsFullCreditUsed',
#        'NumActiveFullCLinesFullCreditUsed', 'NumActiveCCards75pCreditUsed',
#        'NumActiveCLines75pCreditUsed', '%AverageUseOfCCardLoans',
#        '%AverageUseOfCLines2Yrs', '%AverageUseOfCCards1Yr',
#        '%AverageUseOfCLines6MoMiss1',
#        'AverageTenureofActiveRevolveCardsinDays', 'TenureofOldestCCardsinDays',
#        'TenureofOldestRevolvingCCardsinDays', 'NumOfDaysonlastmissedCLine',
#        'TenureofOldestCLineinDays', 'MaxTenureonAutoLoansinDays',
#        'MaxTenureonEduLoansinDays', 'SumTenureonActiveCCardsinMonth',
#        'SumTenureonActiveCLinesinMonth', 'NumOfCLineslast6MoMiss1',
#        'NumOfRevolveCCardslast2YrMiss1', 'NumActiveCLines',
#        'NumCCardsActiveTenure2Yrs', 'ActivatedCLinesinlast2Yrs',
#        'NumActiveCLinesDeliquent', '%UseCLinesonEduLoan',
#        '%UseCLinesonAutoLoan', 'FinanceStressIndex',
#        'NumberCLinesPaidHighRisk', 'DebtRatio1Max', 'NumOfHomeLoansMissed2x',
#        'NumOfAutoLoansMissed2x', 'form_field48', 'form_field49',
#        'DebtRatio1Min', 'ProductApplicatn', 'default_status'],
#       dtype='object')

# %%
new_columns = ['Creditworthiness_score', 'CreditEnquiredRisk',
       'LoanDefaultSeverityAll', 'LoanDefaultSeverityAuto',
       'LoanDefaultSeverityEdu', 'MinCreditAvailAfterPayments',
       'MaxCreditAvailActiveAll', 'MaxCreditAvailAfterPayments',
       'SumOfAvailCreditMissed1Pay', 'TotalCreditAvailActiveAll',
       'PostDefaultDuesCollectedA500', 'TotalDueActive',
       'AllAnnualPaidPreviousYear', 'AnnualIncome', 'PropertyMarketValue',
       'NumActiveCCardsPaidOffFullCreditUsed', 'NumActiveCCardsFullCreditUsed',
       'NumActiveFullCLinesFullCreditUsed', 'NumActiveCCards75pCreditUsed',
       'NumActiveCLines75pCreditUsed', '%AverageUseOfCCardLoans',
       '%AverageUseOfCLines2Yrs', '%AverageUseOfCCards1Yr',
       '%AverageUseOfCLines6MoMiss1',
       'AverageTenureofActiveRevolveCardsinDays', 'TenureofOldestCCardsinDays',
       'TenureofOldestRevolvingCCardsinDays', 'NumOfDaysonlastmissedCLine',
       'TenureofOldestCLineinDays', 'MaxTenureonAutoLoansinDays',
       'MaxTenureonEduLoansinDays', 'SumTenureonActiveCCardsinMonth',
       'SumTenureonActiveCLinesinMonth', 'NumOfCLineslast6MoMiss1',
       'NumOfRevolveCCardslast2YrMiss1', 'NumActiveCLines',
       'NumCCardsActiveTenure2Yrs', 'ActivatedCLinesinlast2Yrs',
       'NumActiveCLinesDeliquent', '%UseCLinesonEduLoan',
       '%UseCLinesonAutoLoan', 'FinanceStressIndex',
       'NumberCLinesPaidHighRisk', 'DebtRatio1Max', 'NumOfHomeLoansMissed2x',
       'NumOfAutoLoansMissed2x', 'form_field48', 'form_field49',
       'DebtRatio1Min', 'ProductApplicatn']

# %%
test_final = test_rename[new_columns]

# %%
test_final.head()
# Out:
#    Creditworthiness_score  CreditEnquiredRisk  LoanDefaultSeverityAll  \
# 0             3236.000000             0.34875                 10.2006
# 1             3284.000000             1.27360                  2.9606
# 2             3492.284404             0.27505                  0.0600
# 3             3232.000000             0.28505                  2.8032
# 4             3466.000000             2.09545                  0.8318
#
#    LoanDefaultSeverityAuto  LoanDefaultSeverityEdu  \
# 0                   0.0000                     0.0
# 1                   9.0198                     0.0
# 2                   0.0000                     0.0
# 3                   0.0000                     0.0
# 4                   2.5182                     0.0
#
#    MinCreditAvailAfterPayments  MaxCreditAvailActiveAll  \
# 0                     418564.0                 418564.0
# 1                          0.0                9858816.0
# 2                          0.0                      0.0
# 3                          0.0                 473802.0
# 4                      19839.0                1150662.0
#
#    MaxCreditAvailAfterPayments  SumOfAvailCreditMissed1Pay  \
# 0                     418564.0                    540710.0
# 1                      49014.0                   1510098.0
# 2                          0.0                         0.0
# 3                     473802.0                   1724437.0
# 4                    1150662.0                   7860523.0
#
#    TotalCreditAvailActiveAll  ...  %UseCLinesonAutoLoan  FinanceStressIndex  \
# 0                        0.0  ...                0.0000            0.825000
# 1                 18308285.0  ...               18.8415            0.507694
# 2                        0.0  ...                0.0000            0.000000
# 3                   493641.0  ...                0.0000            0.916663
# 4                  5752921.0  ...                0.0000            0.234047
#
#    NumberCLinesPaidHighRisk  DebtRatio1Max  NumOfHomeLoansMissed2x  \
# 0                      1.01       0.800000                     0.0
# 1                      4.04       0.623248                     1.0
# 2                      0.00       0.000000                     0.0
# 3                      2.02       0.464224                     0.0
# 4                     23.23       0.726688                     0.0
#
#    NumOfAutoLoansMissed2x  form_field48  form_field49  DebtRatio1Min  \
# 0                     0.0      0.000000      0.000000       0.011221
# 1                     0.0      0.000000      0.504974       0.043525
# 2                     0.0      0.000000      0.000000       0.000000
# 3                     0.0     90.163742      0.788809       0.104029
# 4                     0.0   1303.587148      1.637733       0.163124
#
#    ProductApplicatn
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0
#
# [5 rows x 50 columns]

# %%
#test_final.columns

# %%
#test_final2 = test_final.drop(['DebtRatio1'], axis=1)

# %%
#test_final.columns

# %%
test.shape
# Out:
# (24000, 51)

# %%
test_final.shape
# Out:
# (24000, 50)

# %%
train_feature.shape
# Out:
# (56000, 51)

# %%
test_final = MinMaxScaler().fit_transform(test_final)

# %%
submissions = pd.DataFrame()
submissions['Applicant_ID'] = test_rename['Applicant_ID']

# %%
# predict with probability of 80 % and above
y_pred_proba = pipeline.predict(test_final)#[:,1]
#y_pred_proba = logistic_regression.predict_proba(test_final2)[:,1]
y_pred = (y_pred_proba >= 0.8).astype('int')
#submissions['probability (%)'] = y_pred_proba*100

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
len(y_pred)
# Out:
# 24000

# %%
submissions['default_status'] = y_pred

# %%
submissions.head()
# Out:
#     Applicant_ID  default_status
# 0  Apcnt_1000032               1
# 1  Apcnt_1000048               1
# 2  Apcnt_1000052               1
# 3  Apcnt_1000076               0
# 4  Apcnt_1000080               1

# %%
len(submissions)
# Out:
# 24000

# %%
submissions.to_csv('submissions_F.csv', index=False)
